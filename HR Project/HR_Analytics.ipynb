# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Lets import the required dataset
df=pd.read_csv('E:\Datasets\IBM_HR_Attrition_Rate_Analytics-master\IBM_HR_Attrition_Rate_Analytics-master\WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#lets chcekk the null values
df.isnull().sum()
#here we can see in above dataset there are no null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#lets chcek the datatypes
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#there is  column employe number in the dataset that we can drop as it does not helps so we drop
df.drop(columns=["EmployeeNumber"],inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
# 3                 3          4  Life Sciences              1
# 4                 2          1        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# ...

# %%
#lets see over18 column
df["Over18"].unique()
#this columnn has only one value throughout the dataset so it will not help us in any way so lets drop
# Out:
# array(['Y'], dtype=object)

# %%
df.drop(columns=["Over18"],inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
# 3                 3          4  Life Sciences              1
# 4                 2          1        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# ...

# %%
#Lets check the count of attrition

sns.countplot(x="Attrition",data=df)
plt.show()

# %% [markdown]
# - so this is a higly imbalanced dataset,here out of every 7 employee 1 is facing attrition

# %%
#Lets see average age of employees who is leaving to that who are staying
sns.barplot(x="Attrition",y="Age",data=df)
plt.show()

# %% [markdown]
# - graph shows that people who are staying has averge more

# %%
#Lets check the count of employees based on buisness travel
sns.countplot(x="BusinessTravel",data=df)
plt.show()

# %% [markdown]
# - most of the employee travel rarely

# %%
#Lets see the count of each category of buisness travel where employee attrition is true
sns.countplot(x="BusinessTravel",data=df,hue="Attrition")
plt.show()

# %% [markdown]
# - it can be concluded that proportion of attrition is higher where travel is frequent

# %%
#lets check in which department attrintion is high
sns.countplot(x="Department",data=df,hue="Attrition")
plt.show()

# %% [markdown]
# - here if we compare ratio then in sales 1 out of 4 employee attrition is there
#   in R&D it is 1 of 9

# %%
#lets chcek when distance from home is above 15 kms whats the attrition
sns.countplot(x="Attrition",data=df.loc[df["DistanceFromHome"]>15])
plt.show()

# %%
#Lets chcek the attrition in each job role
plt.figure(figsize=(24,4))
sns.countplot(x="JobRole",data=df,hue="Attrition")
plt.show()
#so we can analyse the attrition ratio in each category and take corrective actions by understanding the reason behind the attrition

# %%
#lets chcek the attrition ratio based on gender
sns.countplot(x="Gender",data=df,hue="Attrition")
plt.show()

# %%
#lets chcek the attrition ratio based on job satisfaction
sns.countplot(x="JobSatisfaction",data=df,hue="Attrition")
plt.show()

# %% [markdown]
# - job satisfaction increases proportion of aleavers decreases

# %%
#Lets chcek the attrition ratio in MaritalStatus
sns.countplot(x="MaritalStatus",data=df,hue="Attrition")
plt.show()

# %% [markdown]
# - in singles ratio is higher

# %%
#Lets compare check the proportion of attrition based on overtime
sns.countplot(x="OverTime",data=df,hue="Attrition")
plt.show()

# %% [markdown]
# - graph clearly shows if overtime is there then attrition proportion is higher

# %%
sns.countplot(x="YearsWithCurrManager",data=df.loc[df["Attrition"]=="Yes"])
plt.show()

# %% [markdown]
# - here we came to know that if years working wth current manager is 0 then attrition was very high
# - Also after 2 years and 7 years of working significant amount of people left

# %%
#lets chcek the work life balance with attrition
sns.countplot(x="WorkLifeBalance",data=df.loc[df["Attrition"]=="Yes"])
plt.show()

# %%
# average working years of the employee who left and who stayed
sns.barplot(x="Attrition",y="YearsAtCompany",data=df)
plt.show()
# so here we get what is the average number of years employee is staying in the company before leaving

# %%
#Lets check the time laped since  last promotion
df.loc[df["Attrition"]=="Yes"].groupby(["YearsSinceLastPromotion"]).agg({"Attrition":"count"})
#here majority almost half of people left not even single year passed since last promotion
#we can conclude promotion is not the factr why people left the company
# Out:
#                          Attrition
# YearsSinceLastPromotion
# 0                              110
# 1                               49
# 2                               27
# 3                                9
# 4                                5
# 5                                2
# 6                                6
# 7                               16
# 9                                4
# 10                               1
# 11                               2
# 13                               2
# 14                               1
# 15                               3

# %%
#Now lets check how performnce rating is afecting attrition level
sns.countplot(x="PerformanceRating",data=df.loc[df["Attrition"]=="Yes"])
plt.show()
#may be since they expect that their work deserves more rating and is undervalued
#almost all the people who left were who got ating 3

# %%
df["EmployeeCount"].unique()
#Here we see that EmployeeCount is having same vaue in entire dataset
# Out:
# array([1], dtype=int64)

# %%
#Lets drop EmployeeCount column
df.drop(columns=["EmployeeCount"],inplace=True)

# %%
df["StandardHours"].unique()
#Here we see that StandardHours has same value throughout
# Out:
# array([80], dtype=int64)

# %%
#Lets drop StandardHours as it will not proovide any infrmation
df.drop(columns=["StandardHours"],inplace=True)

# %%
#lets see correlation matrix
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
#lets chcek the skewness in the dataset
print(df.skew())
print("Total count of numeric features: ",len(df.skew()))
print("count of features which are significantly skewed: ",len(df.skew().loc[abs(df.skew())>0.6]))
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64
# Total count of numeric features:  23
# ...

# %%
#lets seprate the input and output column
df_x=df.drop(columns=["Attrition"])
y=df[["Attrition"]]

# %%
#lets treat the skewness in the input dataset
import numpy as np
for index in df_x.skew().index:
    if df_x.skew().loc[index]>0.6:
        df_x[index]=np.log1p(df_x[index])
    if df_x.skew().loc[index]<-0.6:
        df_x[index]=np.square(df_x[index])

# %%
#Lets again check the skewness
print(df_x.skew())
print("Total count of numeric features: ",len(df_x.skew()))
print("count of features which are significantly skewed: ",len(df_x.skew().loc[abs(df_x.skew())>0.6]))
#Based on below o/p we can say we have reduced significantly skewed features from 14 to 3
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobSatisfaction            -0.329672
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# PercentSalaryHike           0.513543
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.271963
# TotalWorkingYears           0.322355
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.207708
# YearsInCurrentRole         -0.383498
# YearsSinceLastPromotion     0.718805
# YearsWithCurrManager       -0.357686
# dtype: float64
# Total count of numeric features:  23
# ...

# %%
#Lets count the number of columns of object datatype
print(df_x.dtypes.loc[df_x.dtypes=="object"])
# Out:
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# OverTime          object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
y['Attrition']=le.fit_transform(y['Attrition'])
df_x['BusinessTravel']=le.fit_transform(df_x['BusinessTravel'])
df_x['Department']=le.fit_transform(df_x['Department'])
df_x['EducationField']=le.fit_transform(df_x['EducationField'])
df_x['Gender']=le.fit_transform(df_x['Gender'])
df_x['JobRole']=le.fit_transform(df_x['JobRole'])
df_x['MaritalStatus']=le.fit_transform(df_x['MaritalStatus'])
df_x['OverTime']=le.fit_transform(df_x['OverTime'])

# %%
df_x.sample()
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1249   29               2        428           2          2.302585          3
#
#       EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1249               2                        2       0          52
#
#       JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 1249               1  0.693147        8                2              2
#
#       MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 1249       7.923348        14630            0.693147         0
#
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1249           2.639057           1.386294                         3
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1249               0.0           1.206949                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
y.head()
# Out:
#    Attrition
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0

# %%
from scipy.stats import zscore
z = np.abs(zscore(df_x))
z
# Out:
# array([[0.4463504 , 0.59004834, 0.74252653, ..., 0.29061127, 0.97334237,
#         0.54799589],
#        [1.32236521, 0.91319439, 1.2977746 , ..., 0.88267046, 0.11727147,
#         0.90492352],
#        [0.008343  , 0.59004834, 1.41436324, ..., 1.73678265, 0.97334237,
#         1.67504313],
#        ...,
#        [1.08667552, 0.59004834, 1.60518328, ..., 0.352871  , 0.97334237,
#         0.04493464],
#        [1.32236521, 0.91319439, 0.54667746, ..., 0.71446221, 0.97334237,
#         1.05105714],
#        [0.32016256, 0.59004834, 0.43256792, ..., 0.00951942, 0.11727147,
#         0.311993  ]])

# %%
np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# - None of data have a z score greater than 3

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_calc():
    vif_hr=pd.DataFrame()
    vif_hr['VIF_Factor']= [variance_inflation_factor(df_x.values, i) for i in range(df_x.shape[1])]
    vif_hr['features names']=df_x.columns
    print(vif_hr)

# %%
vif_calc()
# Out:
#     VIF_Factor            features names
# 0    35.142857                       Age
# 1     6.946784            BusinessTravel
# 2     5.059000                 DailyRate
# 3    13.181293                Department
# 4     6.396727          DistanceFromHome
# 5     9.654467                 Education
# 6     3.910349            EducationField
# 7     7.254261   EnvironmentSatisfaction
# 8     2.544288                    Gender
# 9    11.705586                HourlyRate
# 10   15.823935            JobInvolvement
# 11   57.418639                  JobLevel
# 12    8.147251                   JobRole
# 13    7.227486           JobSatisfaction
# 14    7.096390             MaritalStatus
# 15  484.104322             MonthlyIncome
# 16    5.126188               MonthlyRate
# 17    5.040405        NumCompaniesWorked
# 18    1.437146                  OverTime
# 19  359.733567         PercentSalaryHike
# 20  571.345184         PerformanceRating
# 21    7.394145  RelationshipSatisfaction
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mms_hr = MinMaxScaler()
df_x = mms_hr.fit_transform(df_x)
df_x
# Out:
# array([[0.54761905, 1.        , 0.71581961, ..., 0.54660257, 0.        ,
#         0.61990623],
#        [0.73809524, 0.5       , 0.12670007, ..., 0.70622674, 0.25      ,
#         0.7194374 ],
#        [0.45238095, 1.        , 0.90980673, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.21428571, 1.        , 0.03793844, ..., 0.3731143 , 0.        ,
#         0.47962493],
#        [0.73809524, 0.5       , 0.65926986, ..., 0.66087637, 0.        ,
#         0.76018753],
#        [0.38095238, 1.        , 0.37652112, ..., 0.47081783, 0.25      ,
#         0.38009377]])

# %% [markdown]
# #### SMOTE for imbalance

# %%
# Before proceeding with model building we need to apply SMOTE since the data is imbalanced
from imblearn.over_sampling import SMOTE

# %%
smt_hr = SMOTE()
train_df_x, train_y = smt_hr.fit_resample(df_x,y)

# %%
train_y.value_counts()
# Out:
# Attrition
# 0            1233
# 1            1233
# dtype: int64

# %%
sns.countplot(data = train_y,x ='Attrition')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# # Algorithm training and testing

# %%
# Importing the model libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lg_hr = LogisticRegression()
gnb_hr = GaussianNB()
svc_hr = SVC()
dtc_hr = DecisionTreeClassifier()
knn_hr = KNeighborsClassifier()
rfc_hr = RandomForestClassifier()
gbc_hr = GradientBoostingClassifier()

model = [lg_hr, gnb_hr, svc_hr, dtc_hr, knn_hr, rfc_hr, gbc_hr]

# %%
# Maximum accuracy
maxAccu_hr = 0 

# Best random state value for which accuracy is achieved 
maxRS_hr = 0
for m in model:
    for i in range(0,500):
        x_train, x_test, y_train, y_test= train_test_split(train_df_x,train_y,test_size= 0.2, random_state=i)
        m.fit(x_train, y_train)
        train_score_hr = m.score(x_train, y_train)
        test_score_hr = m.score(x_train, y_train)
        pred_hr = m.predict(x_test)
        print(f'----------------At random State {i} ------------------')
        acc_hr = accuracy_score(y_test, pred_hr)
        print("Accuracy score of ", m, 'is:', acc_hr)
        print(f'Training score of {m} is {train_score_hr}')
        print(f'Testing score of {m} is {test_score_hr}')
        print('\n')
    
        if acc_hr > maxAccu_hr:
            maxAccu_hr = acc_hr
            maxRS_hr = i
            print(f"Maximum accuracy score of {m} is {acc_hr} at Random state {i}")
            print('\n')
    print('*'*120)
# Out:
# ----------------At random State 0 ------------------
# Accuracy score of  LogisticRegression() is: 0.7672064777327935
# Training score of LogisticRegression() is 0.8062880324543611
# Testing score of LogisticRegression() is 0.8062880324543611
#
#
# Maximum accuracy score of LogisticRegression() is 0.7672064777327935 at Random state 0
#
#
# ----------------At random State 1 ------------------
# Accuracy score of  LogisticRegression() is: 0.757085020242915
# Training score of LogisticRegression() is 0.8118661257606491
# Testing score of LogisticRegression() is 0.8118661257606491
#
#
# ----------------At random State 2 ------------------
# Accuracy score of  LogisticRegression() is: 0.7813765182186235
# Training score of LogisticRegression() is 0.8067951318458418
# Testing score of LogisticRegression() is 0.8067951318458418
#
#
# Maximum accuracy score of LogisticRegression() is 0.7813765182186235 at Random state 2
#
#
# ----------------At random State 3 ------------------
# ...

# %%
print(f"Maximum accuracy score of {m} is {acc_hr} at Random state {i}")
# Out:
# Maximum accuracy score of GradientBoostingClassifier() is 0.9433198380566802 at Random state 499

# %% [markdown]
# #### Cross validation of all the Algorithms

# %%
# Before proceeding with the hpyer parameter tunning we will check for cross validation
from sklearn.model_selection import cross_val_score
max_cvscore_hr = 0 
max_cv_hr = 0
for m in model:
    print(f'---------------------- Cross Validation of {m} --------------------------')
    for j in range(2,15):
        cv_score_hr = cross_val_score(m, df_x,y,cv=j)
        cv_mean_hr = cv_score_hr.mean()
        print(f"At cross fold {j} the cv score is {cv_mean_hr}")
        print('\n') 
    
        if cv_mean_hr > max_cvscore_hr:
            max_cvscore_hr=cv_mean_hr
            max_cv_hr = j
            print(f"At cross fold {j} the Maximum CV score is {max_cvscore_hr}")
            print('\n') 
    print('*'*120)
    print('\n')
# Out:
# ---------------------- Cross Validation of LogisticRegression() --------------------------
# At cross fold 2 the cv score is 0.8700680272108843
#
#
# At cross fold 2 the Maximum CV score is 0.8700680272108843
#
#
# At cross fold 3 the cv score is 0.8734693877551022
#
#
# At cross fold 3 the Maximum CV score is 0.8734693877551022
#
#
# At cross fold 4 the cv score is 0.8700761165738656
#
#
# At cross fold 5 the cv score is 0.8721088435374149
#
#
# At cross fold 6 the cv score is 0.8714285714285714
#
#
# At cross fold 7 the cv score is 0.8741496598639458
#
#
# At cross fold 7 the Maximum CV score is 0.8741496598639458
#
#
# At cross fold 8 the cv score is 0.8707531480161559
#
#
# At cross fold 9 the cv score is 0.8734766488769182
#
#
# At cross fold 10 the cv score is 0.8755102040816325
#
#
# At cross fold 10 the Maximum CV score is 0.8755102040816325
#
#
# At cross fold 11 the cv score is 0.8721294416502584
#
#
# At cross fold 12 the cv score is 0.8721067128704075
#
#
# ...

# %% [markdown]
# Training each algorithm for Random state 499

# %%
for m in model:
    x_train, x_test, y_train, y_test= train_test_split(train_df_x,train_y,test_size= 0.2, random_state=499)
    m.fit(x_train, y_train)
    train_score_hr = m.score(x_train, y_train)
    test_score_hr = m.score(x_train, y_train)
    pred_hr = m.predict(x_test)
    print(f'--------------------- {m} ----------------------')
    acc_hr = accuracy_score(y_test, pred_hr)
    print("Accuracy score of ", m, 'is:', acc_hr)
    print(f'Training score of {m} is {train_score_hr}')
    print(f'Testing score of {m} is {test_score_hr}')
    print("Confusion Matrix:\n",confusion_matrix(y_test, pred_hr))
    print('Classification Report:\n',classification_report(y_test, pred_hr))
    print('*'*120,'\n')
# Out:
# --------------------- LogisticRegression() ----------------------
# Accuracy score of  LogisticRegression() is: 0.8016194331983806
# Training score of LogisticRegression() is 0.7941176470588235
# Testing score of LogisticRegression() is 0.7941176470588235
# Confusion Matrix:
#  [[190  60]
#  [ 38 206]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       250
#            1       0.77      0.84      0.81       244
#
#     accuracy                           0.80       494
#    macro avg       0.80      0.80      0.80       494
# weighted avg       0.80      0.80      0.80       494
#
# ************************************************************************************************************************
#
# --------------------- GaussianNB() ----------------------
# Accuracy score of  GaussianNB() is: 0.7530364372469636
# Training score of GaussianNB() is 0.7302231237322515
# ...

# %% [markdown]
#  - Random Forest calssifier is giving the best results and the next algorithm with best results is Gradien Boosting Classifier

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Tunning with Logistic Regression

# %%
param_lg = { 'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
             'multi_class': ['auto', 'ovr', 'multinomial'],
             'penalty': ['l1', 'l2', 'elasticnet'],
              'C':[100, 10, 1.0, 0.1, 0.01]}

gcv_lg_hr = GridSearchCV(lg_hr,param_lg,cv=10,scoring= 'accuracy')

# training
gcv_lg_hr.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_lg_hr.best_params_)

print("Best Estimator:",gcv_lg_hr.best_estimator_)

gcv_lg_pred_hr=gcv_lg_hr.best_estimator_.predict(x_test)

print('Final Accuracy with Logistic Regression:', accuracy_score(y_test,gcv_lg_pred_hr))
# Out:
# Best parameters: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Best Estimator: LogisticRegression(C=0.1, multi_class='multinomial', solver='newton-cg')
# Final Accuracy with Logistic Regression: 0.8097165991902834

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv_lg_hr.best_estimator_, x_test, y_test)
plt.title("-------ROC AUC plot-------")
plt.show()

# %% [markdown]
# Tunning with GaussianNB

# %%
param_gnb = {'var_smoothing': np.logspace(0,-9, num=100)}

gcv_gnb_hr = GridSearchCV(gnb_hr,param_gnb,cv=14,scoring= 'accuracy')

# training
gcv_gnb_hr.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_gnb_hr.best_params_)

print("Best Estimator:",gcv_gnb_hr.best_estimator_)

gcv_gnb_pred_hr=gcv_gnb_hr.best_estimator_.predict(x_test)

print('Final Accuracy with Gaussian Naive Bayes:', accuracy_score(y_test,gcv_gnb_pred_hr))
# Out:
# Best parameters: {'var_smoothing': 0.01519911082952933}
# Best Estimator: GaussianNB(var_smoothing=0.01519911082952933)
# Final Accuracy with Gaussian Naive Bayes: 0.7449392712550608

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv_gnb_hr.best_estimator_, x_test, y_test)
plt.title("-------ROC AUC plot-------")
plt.show()

# %% [markdown]
# ### Tunning with support vector classifier

# %%
param_svc = {"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}

gcv_svc_hr = GridSearchCV(svc_hr,param_svc,cv=14,scoring= 'accuracy')

# training
gcv_svc_hr.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_svc_hr.best_params_)

print("Best Estimator:",gcv_svc_hr.best_estimator_)

gcv_svc_pred_hr=gcv_svc_hr.best_estimator_.predict(x_test)

print('Final Accuracy with Support Vector Classifier:', accuracy_score(y_test,gcv_svc_pred_hr))
# Out:
# Best parameters: {'C': 10, 'kernel': 'rbf'}
# Best Estimator: SVC(C=10)
# Final Accuracy with Support Vector Classifier: 0.9473684210526315

# %%
# ROC ROC curve
plot_roc_curve(gcv_svc_hr.best_estimator_, x_test, y_test)
plt.title("-------ROC AUC plot-------")
plt.show()

# %% [markdown]
# #### Tunning with Decision Tree Classifier

# %%
param_dtc = {'max_depth': [2, 3, 5, 10, 20],'min_samples_leaf': [5, 10, 20, 50, 100],'criterion': ["gini", "entropy"]}

gcv_dtc_hr = GridSearchCV(dtc_hr,param_dtc,cv=14,scoring= 'accuracy')

# training
gcv_dtc_hr.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_dtc_hr.best_params_)

print("Best Estimator:",gcv_dtc_hr.best_estimator_)

gcv_dtc_pred_hr=gcv_dtc_hr.best_estimator_.predict(x_test)

print('Final Accuracy with Decision Tree Classifier:', accuracy_score(y_test,gcv_dtc_pred_hr))
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10}
# Best Estimator: DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=10)
# Final Accuracy with Decision Tree Classifier: 0.8461538461538461

# %%
# ROC ROC curve
plot_roc_curve(gcv_dtc_hr.best_estimator_, x_test, y_test)
plt.title("-------ROC AUC plot-------")
plt.show()

# %% [markdown]
# #### Tunning with K Neighbor classifier

# %%
param_knn = {'n_neighbors' : [5,7,9,11,13,15],
            'weights' : ['uniform','distance'],
            'metric' : ['minkowski','euclidean','manhattan']}

gcv_knn_hr = GridSearchCV(knn_hr,param_knn,cv=14,scoring= 'accuracy')

# training
gcv_knn_hr.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_knn_hr.best_params_)

print("Best Estimator:",gcv_knn_hr.best_estimator_)

gcv_knn_pred_hr=gcv_knn_hr.best_estimator_.predict(x_test)

print('Final Accuracy with K Neighbor Classifier:', accuracy_score(y_test,gcv_knn_pred_hr))
# Out:
# Best parameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Best Estimator: KNeighborsClassifier(metric='manhattan', weights='distance')
# Final Accuracy with K Neighbor Classifier: 0.8927125506072875

# %%
# ROC ROC curve
plot_roc_curve(gcv_knn_hr.best_estimator_, x_test, y_test)
plt.title("-------ROC AUC plot-------")
plt.show()

# %%
# Pickling with Support Vector Classifier
import joblib
joblib.dump(gcv_svc_hr.best_estimator_,"HR_Attrition_SVC.pkl")
# Out:
# ['HR_Attrition_SVC.pkl']

# %%
HR_model_svc = joblib.load('HR_Attrition_SVC.pkl')
HR_result_svc = HR_model_svc.score(x_test, y_test)
print(HR_result_svc*100)
# Out:
# 94.73684210526315
