# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'E:\Datasets\bigdatamart_rep-master\bigdatamart_rep-master\bigdatamart_Train.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
df.sample()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7273           FDM44         12.5          Low Fat         0.051971
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7273  Fruits and Vegetables   103.699            OUT010
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7273                       1998         NaN               Tier 3
#
#         Outlet_Type  Item_Outlet_Sales
# 7273  Grocery Store            412.796

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Checking for unique values of categorical variables
# Creating a list of categorical variables

big_mart_cat = ['Item_Identifier','Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type']

for uq in range(len(big_mart_cat)):
    uniq_big_mart = df[big_mart_cat[uq]].unique()
    print(f'Unique values for {big_mart_cat[uq]}: {uniq_big_mart}')
    print(f"--------- Description of {big_mart_cat[uq]} categorical variable ----------")
    new_bdm = pd.Categorical(df[big_mart_cat[uq]])
    print(new_bdm.describe())
    print('\n')
# Out:
# Unique values for Item_Identifier: ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# --------- Description of Item_Identifier categorical variable ----------
#             counts     freqs
# categories
# DRA12            6  0.000704
# DRA24            7  0.000821
# DRA59            8  0.000939
# DRB01            3  0.000352
# DRB13            5  0.000587
# ...            ...       ...
# NCZ30            7  0.000821
# NCZ41            5  0.000587
# NCZ42            5  0.000587
# NCZ53            5  0.000587
# NCZ54            7  0.000821
#
# [1559 rows x 2 columns]
#
#
# Unique values for Item_Fat_Content: ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# --------- Description of Item_Fat_Content categorical variable ----------
#             counts     freqs
# categories
# LF             316  0.037076
# Low Fat       5089  0.597090
# Regular       2889  0.338965
# low fat        112  0.013141
# reg            117  0.013728
#
#
# Unique values for Item_Type: ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# --------- Description of Item_Type categorical variable ----------
#                        counts     freqs
# categories
# Baking Goods              648  0.076030
# Breads                    251  0.029450
# Breakfast                 110  0.012906
# Canned                    649  0.076147
# Dairy                     682  0.080019
# Frozen Foods              856  0.100434
# Fruits and Vegetables    1232  0.144550
# Hard Drinks               214  0.025109
# Health and Hygiene        520  0.061011
# Household                 910  0.106770
# Meat                      425  0.049865
# Others                    169  0.019829
# Seafood                    64  0.007509
# Snack Foods              1200  0.140795
# Soft Drinks               445  0.052212
# Starchy Foods             148  0.017365
#
#
# Unique values for Outlet_Identifier: ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
# --------- Description of Outlet_Identifier categorical variable ----------
#             counts     freqs
# categories
# OUT010         555  0.065118
# OUT013         932  0.109351
# OUT017         926  0.108647
# OUT018         928  0.108882
# OUT019         528  0.061950
# OUT027         935  0.109703
# OUT035         930  0.109117
# OUT045         929  0.108999
# OUT046         930  0.109117
# OUT049         930  0.109117
#
#
# Unique values for Outlet_Size: ['Medium' nan 'High' 'Small']
# --------- Description of Outlet_Size categorical variable ----------
#             counts     freqs
# categories
# High           932  0.109351
# Medium        2793  0.327702
# Small         2388  0.280183
# NaN           2410  0.282764
#
#
# Unique values for Outlet_Location_Type: ['Tier 1' 'Tier 3' 'Tier 2']
# --------- Description of Outlet_Location_Type categorical variable ----------
#             counts     freqs
# categories
# Tier 1        2388  0.280183
# Tier 2        2785  0.326763
# Tier 3        3350  0.393054
#
#
# Unique values for Outlet_Type: ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']
# --------- Description of Outlet_Type categorical variable ----------
#                    counts     freqs
# categories
# Grocery Store        1083  0.127068
# Supermarket Type1    5577  0.654347
# Supermarket Type2     928  0.108882
# Supermarket Type3     935  0.109703

# %%
#replacing low fat and LF with Low Fat
df["Item_Fat_Content"].replace("low fat","Low Fat",inplace=True)
df["Item_Fat_Content"].replace("LF","Low Fat",inplace=True)

# %%
#replacing reg with Regular
df["Item_Fat_Content"].replace("reg","Regular",inplace=True)

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# We have missing values in Item weight. We cannot directly replace them with mean of that column. 
# We need to group it with item type and replace the missing values with mean of each item type 
item_weight_mean = df.groupby('Item_Type')
item_weight_mean.mean()['Item_Weight']
# Out:
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731
# Name: Item_Weight, dtype: float64

# %%
df['Item_Weight'].fillna(df.groupby('Item_Type')['Item_Weight'].transform('mean'), inplace = True)

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat         0.016047
# 1           DRC01      5.92000          Regular         0.019278
# 2           FDN15     17.50000          Low Fat         0.016760
# 3           FDX07     19.20000          Regular         0.000000
# 4           NCD19      8.93000          Low Fat         0.000000
# 5           FDP36     10.39500          Regular         0.000000
# 6           FDO10     13.65000          Regular         0.012741
# 7           FDP10     12.98788          Low Fat         0.127470
# 8           FDH17     16.20000          Regular         0.016687
# 9           FDU28     19.20000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
plt.xticks(rotation='vertical')
sns.scatterplot(x = 'Item_Type',y = 'Item_Outlet_Sales', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
# Creating two separate list of object data tpye and numerical data type varibales
object_bdm = ['Item_Fat_Content','Item_Type', 'Outlet_Identifier','Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
integer_bdm = ['Item_Weight', 'Item_Visibility','Item_MRP','Outlet_Establishment_Year','Item_Outlet_Sales']

# %%
plt.figure(figsize=(15,15), facecolor ='white')
plot_no = 1

for c in object_bdm:
    if plot_no <= 6:
        ax = plt.subplot(2,3,plot_no)
        plt.xticks(rotation='vertical')
        sns.countplot(x = c, data = df)
        print(df[c].value_counts())
    plot_no += 1

plt.tight_layout()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
# OUT027    935
# OUT013    932
# OUT035    930
# OUT046    930
# OUT049    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
sns.scatterplot(x = 'Item_Weight', y = 'Item_Outlet_Sales', data = df, hue = 'Item_Fat_Content')
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# - Irrespective of low or regular fat or even item weight sales of the outlet increases

# %%
plt.figure(figsize=(15,12), facecolor ='white')
plot_no = 1

for c in object_bdm:
    if plot_no <= 7:
        ax = plt.subplot(2,4,plot_no)
        plt.xticks(rotation='vertical')
        sns.scatterplot(x = c,y = 'Item_Outlet_Sales', data = df)
    plot_no += 1

plt.tight_layout()

# %% [markdown]
# - Sales in outlet 10 and 19 are low compared to others

# %%
# Data was collected in 2013, Lets modify the years column with 2013 - established year to know how old the outlet is
df['Outlet_Establishment_Year']
# Out:
# 0       1999
# 1       2009
# 2       1999
# 3       1998
# 4       1987
#         ...
# 8518    1987
# 8519    2002
# 8520    2004
# 8521    2009
# 8522    1997
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64

# %%
Outlet_years = []
for year in df['Outlet_Establishment_Year']:
    diff = 2013 - year
    Outlet_years.append(diff)

Outlet_years
# Out:
# [14,
#  4,
#  14,
#  15,
#  26,
#  4,
#  26,
#  28,
#  11,
#  6,
#  14,
#  16,
#  14,
#  16,
#  26,
#  16,
#  4,
#  14,
#  28,
#  9,
#  26,
#  28,
#  9,
#  28,
#  16,
#  6,
#  9,
#  26,
#  15,
#  28,
#  15,
#  4,
#  4,
#  11,
#  16,
#  14,
#  28,
#  4,
#  28,
#  28,
#  16,
#  26,
#  14,
#  4,
#  26,
#  15,
#  11,
#  11,
#  16,
#  28,
#  16,
#  26,
#  26,
#  6,
#  6,
#  4,
#  11,
#  14,
#  16,
#  28,
#  4,
#  11,
#  28,
#  28,
#  28,
#  15,
#  9,
#  11,
#  11,
#  16,
#  16,
#  26,
#  11,
#  6,
#  14,
#  16,
#  14,
#  28,
#  6,
#  11,
#  16,
#  16,
#  4,
#  28,
#  28,
#  6,
#  9,
#  28,
#  16,
#  14,
#  15,
#  14,
#  11,
#  9,
#  9,
#  28,
#  14,
#  9,
#  28,
#  16,
#  11,
#  28,
#  14,
#  26,
#  4,
#  26,
#  26,
#  11,
#  28,
#  26,
#  16,
#  6,
#  28,
#  28,
#  11,
#  14,
#  6,
#  9,
#  6,
#  4,
#  6,
#  11,
#  15,
#  9,
#  6,
#  9,
#  16,
#  6,
#  26,
#  11,
#  28,
#  16,
#  28,
#  15,
#  4,
#  16,
#  28,
#  11,
#  6,
#  15,
#  9,
#  6,
#  11,
#  14,
#  9,
#  14,
#  9,
#  9,
#  9,
#  9,
#  6,
#  4,
#  4,
#  28,
#  16,
#  4,
#  4,
#  6,
#  6,
#  26,
#  26,
#  28,
#  4,
#  16,
#  16,
#  6,
#  6,
#  4,
#  28,
#  4,
#  9,
#  6,
#  26,
#  26,
#  15,
#  15,
#  11,
#  15,
#  28,
#  11,
#  28,
#  11,
#  28,
#  26,
#  28,
#  4,
#  28,
#  14,
#  11,
#  14,
#  14,
#  14,
#  11,
#  4,
#  28,
#  16,
#  16,
#  14,
#  28,
#  28,
#  11,
#  9,
#  11,
#  28,
#  16,
#  15,
#  14,
#  11,
#  28,
#  15,
#  9,
#  9,
#  6,
#  11,
#  15,
#  15,
#  15,
#  15,
#  26,
#  9,
#  14,
#  6,
#  16,
#  6,
#  26,
#  28,
#  26,
#  28,
#  9,
#  28,
#  28,
#  28,
#  11,
#  9,
#  16,
#  28,
#  28,
#  26,
#  28,
#  28,
#  11,
#  6,
#  9,
#  6,
#  9,
#  9,
#  26,
#  9,
#  14,
#  6,
#  28,
#  4,
#  14,
#  26,
#  11,
#  28,
#  6,
#  26,
#  11,
#  6,
#  26,
#  9,
#  6,
#  11,
#  11,
#  26,
#  26,
#  26,
#  6,
#  26,
#  16,
#  26,
#  26,
#  9,
#  16,
#  28,
#  26,
#  6,
#  15,
#  28,
#  4,
#  9,
#  28,
#  6,
#  28,
#  9,
#  15,
#  4,
#  9,
#  14,
#  11,
#  28,
#  11,
#  4,
#  28,
#  14,
#  9,
#  16,
#  6,
#  16,
#  28,
#  28,
#  9,
#  4,
#  11,
#  6,
#  11,
#  4,
#  16,
#  9,
#  9,
#  16,
#  16,
#  28,
#  26,
#  11,
#  11,
#  15,
#  11,
#  28,
#  28,
#  14,
#  6,
#  6,
#  14,
#  15,
#  26,
#  11,
#  28,
#  11,
#  26,
#  28,
#  11,
#  28,
#  28,
#  28,
#  16,
#  11,
#  6,
#  6,
#  28,
#  26,
#  26,
#  11,
#  28,
#  14,
#  14,
#  14,
#  14,
#  4,
#  4,
#  11,
#  26,
#  16,
#  14,
#  16,
#  16,
#  28,
#  16,
#  28,
#  4,
#  16,
#  11,
#  14,
#  28,
#  26,
#  9,
#  6,
#  4,
#  6,
#  28,
#  28,
#  11,
#  9,
#  26,
#  4,
#  16,
#  26,
#  26,
#  9,
#  28,
#  28,
#  4,
#  6,
#  16,
#  9,
#  9,
#  15,
#  28,
#  16,
#  16,
#  11,
#  16,
#  28,
#  11,
#  14,
#  14,
#  16,
#  4,
#  11,
#  28,
#  11,
#  9,
#  16,
#  28,
#  28,
#  14,
#  16,
#  26,
#  28,
#  16,
#  15,
#  4,
#  16,
#  16,
#  6,
#  9,
#  28,
#  11,
#  6,
#  15,
#  11,
#  14,
#  4,
#  14,
#  14,
#  4,
#  4,
#  11,
#  11,
#  28,
#  16,
#  14,
#  28,
#  28,
#  26,
#  16,
#  11,
#  14,
#  26,
#  16,
#  16,
#  11,
#  14,
#  4,
#  9,
#  28,
#  26,
#  6,
#  28,
#  9,
#  16,
#  4,
#  11,
#  26,
#  9,
#  28,
#  16,
#  28,
#  26,
#  26,
#  6,
#  16,
#  6,
#  4,
#  9,
#  26,
#  6,
#  11,
#  4,
#  11,
#  11,
#  28,
#  14,
#  16,
#  16,
#  9,
#  15,
#  11,
#  11,
#  26,
#  9,
#  16,
#  15,
#  9,
#  28,
#  11,
#  28,
#  16,
#  28,
#  28,
#  28,
#  6,
#  15,
#  9,
#  14,
#  26,
#  28,
#  9,
#  11,
#  6,
#  14,
#  15,
#  6,
#  28,
#  4,
#  4,
#  6,
#  9,
#  28,
#  15,
#  11,
#  4,
#  11,
#  26,
#  11,
#  11,
#  4,
#  28,
#  28,
#  26,
#  15,
#  15,
#  26,
#  11,
#  16,
#  4,
#  28,
#  6,
#  11,
#  26,
#  15,
#  15,
#  14,
#  6,
#  16,
#  9,
#  28,
#  16,
#  9,
#  15,
#  6,
#  28,
#  26,
#  9,
#  28,
#  14,
#  15,
#  11,
#  14,
#  9,
#  16,
#  28,
#  16,
#  6,
#  6,
#  28,
#  28,
#  6,
#  11,
#  4,
#  15,
#  14,
#  28,
#  9,
#  26,
#  11,
#  14,
#  14,
#  11,
#  6,
#  4,
#  11,
#  4,
#  28,
#  4,
#  16,
#  9,
#  26,
#  14,
#  14,
#  6,
#  4,
#  11,
#  16,
#  9,
#  11,
#  26,
#  28,
#  16,
#  11,
#  6,
#  9,
#  26,
#  16,
#  11,
#  4,
#  6,
#  28,
#  16,
#  16,
#  16,
#  4,
#  14,
#  16,
#  9,
#  11,
#  9,
#  6,
#  16,
#  28,
#  11,
#  26,
#  26,
#  11,
#  9,
#  6,
#  26,
#  26,
#  11,
#  14,
#  14,
#  4,
#  4,
#  11,
#  9,
#  4,
#  14,
#  28,
#  9,
#  28,
#  11,
#  4,
#  28,
#  26,
#  28,
#  15,
#  16,
#  26,
#  16,
#  28,
#  4,
#  6,
#  4,
#  4,
#  11,
#  6,
#  14,
#  9,
#  26,
#  6,
#  15,
#  11,
#  4,
#  16,
#  16,
#  4,
#  4,
#  26,
#  14,
#  9,
#  28,
#  6,
#  26,
#  4,
#  26,
#  26,
#  26,
#  14,
#  28,
#  4,
#  4,
#  14,
#  6,
#  4,
#  16,
#  4,
#  26,
#  4,
#  6,
#  15,
#  9,
#  6,
#  14,
#  14,
#  28,
#  14,
#  15,
#  9,
#  11,
#  26,
#  11,
#  28,
#  11,
#  28,
#  28,
#  26,
#  14,
#  28,
#  9,
#  28,
#  9,
#  6,
#  9,
#  14,
#  16,
#  15,
#  16,
#  26,
#  16,
#  16,
#  11,
#  15,
#  14,
#  16,
#  28,
#  4,
#  4,
#  16,
#  6,
#  4,
#  28,
#  16,
#  28,
#  6,
#  28,
#  28,
#  14,
#  16,
#  16,
#  11,
#  26,
#  14,
#  11,
#  9,
#  6,
#  9,
#  14,
#  6,
#  28,
#  6,
#  6,
#  28,
#  16,
#  14,
#  14,
#  15,
#  9,
#  9,
#  16,
#  6,
#  9,
#  28,
#  16,
#  9,
#  16,
#  11,
#  16,
#  28,
#  15,
#  26,
#  26,
#  4,
#  11,
#  16,
#  14,
#  26,
#  14,
#  11,
#  26,
#  28,
#  28,
#  6,
#  26,
#  28,
#  28,
#  9,
#  9,
#  11,
#  11,
#  4,
#  11,
#  26,
#  28,
#  11,
#  16,
#  11,
#  15,
#  9,
#  26,
#  26,
#  14,
#  6,
#  28,
#  11,
#  28,
#  16,
#  4,
#  9,
#  6,
#  26,
#  11,
#  11,
#  28,
#  26,
#  28,
#  4,
#  14,
#  11,
#  28,
#  9,
#  28,
#  26,
#  9,
#  9,
#  9,
#  26,
#  28,
#  26,
#  16,
#  14,
#  9,
#  14,
#  4,
#  28,
#  9,
#  4,
#  28,
#  15,
#  26,
#  28,
#  11,
#  28,
#  28,
#  26,
#  11,
#  15,
#  28,
#  14,
#  9,
#  9,
#  28,
#  14,
#  4,
#  28,
#  4,
#  16,
#  28,
#  6,
#  28,
#  26,
#  15,
#  26,
#  28,
#  28,
#  16,
#  9,
#  28,
#  28,
#  14,
#  6,
#  15,
#  16,
#  26,
#  11,
#  6,
#  9,
#  28,
#  6,
#  26,
#  26,
#  14,
#  11,
#  16,
#  4,
#  16,
#  28,
#  9,
#  14,
#  11,
#  6,
#  4,
#  15,
#  15,
#  28,
#  26,
#  14,
#  4,
#  16,
#  9,
#  14,
#  4,
#  28,
#  26,
#  6,
#  16,
#  11,
#  28,
#  6,
#  16,
#  28,
#  4,
#  4,
#  14,
#  6,
#  16,
#  15,
#  6,
#  15,
#  4,
#  16,
#  28,
#  26,
#  15,
#  26,
#  14,
#  28,
#  16,
#  28,
#  14,
#  28,
#  4,
#  26,
#  16,
#  28,
#  11,
#  9,
#  28,
#  15,
#  26,
#  14,
#  16,
#  9,
#  28,
#  4,
#  28,
#  26,
#  26,
#  28,
#  14,
#  9,
#  26,
#  6,
#  4,
#  26,
#  15,
#  28,
#  28,
#  28,
#  11,
#  4,
#  26,
#  28,
#  15,
#  16,
#  6,
#  6,
#  11,
#  6,
#  9,
#  28,
#  26,
#  6,
#  11,
#  6,
#  28,
#  15,
#  6,
#  9,
#  9,
#  14,
#  11,
#  11,
#  15,
#  14,
#  9,
#  28,
#  6,
#  15,
#  4,
#  9,
#  28,
#  15,
#  4,
#  4,
#  9,
#  11,
#  26,
#  16,
#  28,
#  16,
#  28,
#  9,
#  6,
#  26,
#  15,
#  9,
#  6,
#  9,
#  28,
#  ...]

# %%
df['Outlet_Establishment_Year'] = Outlet_years

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                         14      Medium               Tier 1
# 1                          4      Medium               Tier 3
# 2                         14      Medium               Tier 1
# 3                         15      Medium               Tier 3
# 4                         26        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Finding the oldest outlet
np.where(df['Outlet_Establishment_Year'] == max(df['Outlet_Establishment_Year']))
# Out:
# (array([   7,   18,   21, ..., 8488, 8490, 8504], dtype=int64),)

# %%
df.loc[np.where(df['Outlet_Establishment_Year'] == max(df['Outlet_Establishment_Year']))]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10    12.987880          Low Fat         0.127470
# 18             DRI11    11.400328          Low Fat         0.034238
# 21             FDW12    12.277108          Regular         0.035400
# 23             FDC37    12.277108          Low Fat         0.057557
# 29             FDC14    12.305705          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37    11.847460          Low Fat         0.043792
# 8487           DRG13    11.847460          Low Fat         0.037006
# 8488           NCN14    13.853285          Low Fat         0.091473
# 8490           FDU44    13.224769          Regular         0.102296
# 8504           NCN18    13.384736          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                            28      Medium               Tier 3
# 18                           28      Medium               Tier 3
# 21                           28      Medium               Tier 3
# 23                           28       Small               Tier 1
# 29                           28       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                         28      Medium               Tier 3
# 8487                         28      Medium               Tier 3
# 8488                         28      Medium               Tier 3
# 8490                         28       Small               Tier 1
# 8504                         28      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %% [markdown]
# - Oldest outlet is 28 years old

# %% [markdown]
# #### Summary Statistics

# %%
df.describe(include = 'all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  8523.000000             8523      8523.000000
# unique            1559          NaN                2              NaN
# top              FDG33          NaN          Low Fat              NaN
# freq                10          NaN             5517              NaN
# mean               NaN    12.857890              NaN         0.066132
# std                NaN     4.232804              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     9.310000              NaN         0.026989
# 50%                NaN    12.867061              NaN         0.053931
# 75%                NaN    16.000000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# unique                     16          NaN                10
# top     Fruits and Vegetables          NaN            OUT027
# freq                     1232          NaN               935
# mean                      NaN   140.992782               NaN
# std                       NaN    62.275067               NaN
# min                       NaN    31.290000               NaN
# 25%                       NaN    93.826500               NaN
# 50%                       NaN   143.012800               NaN
# 75%                       NaN   185.643700               NaN
# max                       NaN   266.888400               NaN
#
#         Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# count                 8523.000000        8523                 8523
# unique                        NaN           3                    3
# top                           NaN      Medium               Tier 3
# freq                          NaN        5203                 3350
# mean                    15.168133         NaN                  NaN
# std                      8.371760         NaN                  NaN
# min                      4.000000         NaN                  NaN
# 25%                      9.000000         NaN                  NaN
# 50%                     14.000000         NaN                  NaN
# 75%                     26.000000         NaN                  NaN
# max                     28.000000         NaN                  NaN
#
#               Outlet_Type  Item_Outlet_Sales
# count                8523        8523.000000
# unique                  4                NaN
# top     Supermarket Type1                NaN
# freq                 5577                NaN
# mean                  NaN        2181.288914
# std                   NaN        1706.499616
# min                   NaN          33.290000
# 25%                   NaN         834.247400
# 50%                   NaN        1794.331000
# 75%                   NaN        3101.296400
# max                   NaN       13086.964800

# %% [markdown]
# #### Correlation

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.011620  0.025821
# Item_Visibility              -0.011620         1.000000 -0.001315
# Item_MRP                      0.025821        -0.001315  1.000000
# Outlet_Establishment_Year     0.008376         0.074834 -0.005020
# Item_Outlet_Sales             0.012088        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                 0.008376           0.012088
# Item_Visibility                             0.074834          -0.128625
# Item_MRP                                   -0.005020           0.567574
# Outlet_Establishment_Year                   1.000000           0.049135
# Item_Outlet_Sales                           0.049135           1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Item MRP is the most correlated with target variable

# %% [markdown]
# #### Checking for skewness

# %%
df.skew()
# Out:
# Item_Weight                  0.089537
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year    0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# #### Checking for Outliers

# %%
df.plot(kind='box', subplots = True, layout = (2,6), figsize = (20,12), title = "Box Plot to check outliers", fontsize = 13)
# Out:
# Item_Weight                     AxesSubplot(0.125,0.536818;0.110714x0.343182)
# Item_Visibility              AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# Item_MRP                     AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# Outlet_Establishment_Year    AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# Item_Outlet_Sales            AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# dtype: object

# %% [markdown]
# - Outliers are present

# %% [markdown]
# #### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Item_Identifier']=le.fit_transform(df['Item_Identifier'])
df['Item_Fat_Content']=le.fit_transform(df['Item_Fat_Content'])
df['Item_Type']=le.fit_transform(df['Item_Type'])
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])
df['Outlet_Size']=le.fit_transform(df['Outlet_Size'])
df['Outlet_Location_Type']=le.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type']=le.fit_transform(df['Outlet_Type'])

# %%
from scipy.stats import zscore
z_big = np.abs(zscore(df))
z_big
# Out:
# array([[1.38851383, 0.84060081, 0.73814723, ..., 1.36933384, 0.25265831,
#         0.910601  ],
#        [1.71799137, 1.63917263, 1.35474328, ..., 1.09156913, 1.00297245,
#         1.01844035],
#        [0.26205684, 1.0967628 , 0.73814723, ..., 1.36933384, 0.25265831,
#         0.04923754],
#        ...,
#        [1.28515188, 0.53345779, 0.73814723, ..., 0.13888236, 0.25265831,
#         0.57909963],
#        [0.21975905, 1.33439226, 1.35474328, ..., 1.09156913, 1.00297245,
#         0.19672492],
#        [1.62449099, 0.45885039, 0.73814723, ..., 1.36933384, 0.25265831,
#         0.82959407]])

# %%
np.where(z_big>3)
# Out:
# (array([  49,   83,  108,  130,  145,  174,  276,  304,  333,  373,  434,
#          456,  472,  502,  521,  532,  661,  694,  753,  809,  854,  935,
#          991,  997, 1009, 1138, 1159, 1254, 1272, 1291, 1311, 1324, 1434,
#         1450, 1496, 1501, 1506, 1560, 1575, 1644, 1651, 1805, 1827, 1841,
#         1859, 1998, 2088, 2109, 2122, 2216, 2238, 2251, 2293, 2324, 2439,
#         2445, 2516, 2535, 2586, 2613, 2728, 2776, 2855, 2895, 3017, 3083,
#         3087, 3098, 3154, 3206, 3234, 3286, 3399, 3407, 3458, 3474, 3488,
#         3497, 3540, 3667, 3709, 3720, 3750, 3757, 3767, 3884, 3993, 4006,
#         4219, 4289, 4346, 4349, 4382, 4408, 4530, 4656, 4674, 4676, 4681,
#         4772, 4789, 4888, 4941, 4961, 4991, 5031, 5065, 5150, 5177, 5185,
#         5223, 5287, 5315, 5374, 5500, 5550, 5619, 5732, 5734, 5752, 5795,
#         5799, 5812, 5837, 5880, 5891, 5946, 5977, 6000, 6008, 6012, 6134,
#         6179, 6334, 6409, 6536, 6537, 6541, 6576, 6606, 6622, 6674, 6786,
#         6886, 6903, 6993, 7005, 7016, 7076, 7088, 7107, 7121, 7188, 7191,
#         7215, 7236, 7250, 7256, 7278, 7302, 7343, 7388, 7499, 7558, 7560,
#         7562, 7603, 7609, 7690, 7744, 7752, 7816, 7826, 7866, 7930, 7949,
#         8039, 8194, 8201, 8215, 8245, 8273, 8345, 8432, 8447], dtype=int64),
#  array([ 3,  3,  3, 11, 11,  3, 11, 11, 11, 11,  3, 11, 11,  3,  3,  3, 11,
#         11, 11, 11,  3, 11, 11, 11, 11, 11,  3, 11,  3,  3,  3,  3,  3, 11,
#          3,  3, 11,  3,  3,  3,  3,  3,  3,  3, 11, 11,  3, 11,  3, 11, 11,
#          3, 11,  3,  3,  3, 11, 11,  3,  3,  3, 11,  3,  3,  3, 11, 11, 11,
#         11,  3, 11, 11,  3, 11,  3,  3,  3,  3,  3, 11, 11, 11,  3, 11,  3,
#          3,  3,  3,  3, 11, 11, 11,  3,  3,  3,  3,  3, 11, 11, 11,  3, 11,
#          3, 11, 11,  3, 11,  3, 11, 11, 11,  3, 11,  3, 11, 11, 11,  3,  3,
#         11,  3, 11, 11,  3,  3,  3,  3, 11, 11,  3,  3, 11,  3, 11, 11,  3,
#         11, 11,  3, 11,  3,  3,  3, 11,  3, 11,  3, 11, 11,  3,  3,  3, 11,
#         11,  3, 11,  3, 11,  3, 11, 11,  3,  3,  3, 11, 11,  3, 11, 11,  3,
#         11, 11, 11,  3, 11,  3, 11,  3, 11,  3, 11,  3,  3,  3, 11],
#        dtype=int64))

# %%
df_new = df[(z_big<3).all(axis=1)]
df_new
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                         14
# 1            14   48.2692                  3                          4
# 2            10  141.6180                  9                         14
# 3             6  182.0950                  0                         15
# 4             9   53.8614                  1                         26
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                         26
# 8519          0  108.1570                  7                         11
# 8520          8   85.1224                  6                          9
# 8521         13  103.1332                  3                          4
# 8522         14   75.4670                  8                         16
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0               1                     0            1          3735.1380
# 1               1                     2            2           443.4228
# 2               1                     0            1          2097.2700
# 3               1                     2            0           732.3800
# 4               0                     2            1           994.7052
# ...           ...                   ...          ...                ...
# 8518            0                     2            1          2778.3834
# 8519            1                     1            1           549.2850
# 8520            2                     1            1          1193.1136
# 8521            1                     2            2          1845.5976
# 8522            2                     0            1           765.6700
#
# [8338 rows x 12 columns]

# %%
# Checking the shape of the dataset before and after removing outliers
print("Old DataFrame:-", df.shape)
print("New DataFrame:-", df_new.shape)
print('Total dropped rows:-', df.shape[0]-df_new.shape[0])
# Out:
# Old DataFrame:- (8523, 12)
# New DataFrame:- (8338, 12)
# Total dropped rows:- 185

# %%
# Percentage loss of data
loss_percent_big = (8523-8338)/8338*100
print(loss_percent_big,'%')
# Out:
# 2.2187574958023504 %

# %% [markdown]
# #### Splitting the data

# %%
X = df_new.iloc[:,:-1]
X.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                         14            1
# 1   48.2692                  3                          4            1
# 2  141.6180                  9                         14            1
# 3  182.0950                  0                         15            1
# 4   53.8614                  1                         26            0
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     2            2
# 2                     0            1
# 3                     2            0
# 4                     2            1

# %%
X.shape
# Out:
# (8338, 11)

# %%
y = df_new.iloc[:,-1]
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8338, dtype: float64

# %%
y.shape
# Out:
# (8338,)

# %% [markdown]
# #### Scaling

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X= scale.fit_transform(X)
X
# Out:
# array([[-1.38690137, -0.83586336, -0.73664489, ..., -0.27887393,
#         -1.37034498, -0.25983859],
#        [-1.71567222, -1.62953762,  1.35750619, ..., -0.27887393,
#          1.09905991,  1.02213428],
#        [-0.2628605 ,  1.08961858, -0.73664489, ..., -0.27887393,
#         -1.37034498, -0.25983859],
#        ...,
#        [ 1.28102962, -0.53060403, -0.73664489, ...,  1.38320672,
#         -0.13564253, -0.25983859],
#        [-0.22065343, -1.32662644,  1.35750619, ..., -0.27887393,
#          1.09905991,  1.02213428],
#        [-1.62237238,  0.45561843, -0.73664489, ...,  1.38320672,
#         -1.37034498, -0.25983859]])

# %%
plt.figure(figsize=(12,6))
plot_no = 1
for column in df_new:
    if plot_no <= 11:
        ax = plt.subplot(3,4,plot_no)
        sns.distplot(df_new[column])
        plt.xlabel(column, fontsize = 15)

    plot_no += 1
plt.tight_layout()

# %% [markdown]
# ### Model Building

# %%
# Importing the libraries for model building
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiating each algorithm
lr_big = LinearRegression()
dtr_big = DecisionTreeRegressor()
knr_big = KNeighborsRegressor()
svr_big = SVR()
rfr_big = RandomForestRegressor()

# List of instantiated algorithms
algm_t = [lr_big, dtr_big, knr_big, svr_big, rfr_big]

# %%
# Maximum accuracy
maxAccu_big = 0 

# Best random state value for which accuracy is achieved 
maxRS_big = 0

for i in range(0,500):
    x_train, x_test,y_train, y_test = train_test_split(X,y, random_state=i, test_size=0.20)
    lr_big.fit(x_train, y_train)
    pred_train_big= lr_big.predict(x_train)
    pred_test_big= lr_big.predict(x_test)
    score_train_big = lr_big.score(x_train, y_train)
    score_test_big = lr_big.score(x_test, y_test)
    r2_lr_big = r2_score(y_test, pred_test_big)
    print(f'----------------At random State {i} ------------------')
    print(f"Training score is {score_train_big}")
    print(f"Testing score is {score_test_big}")
    print(f'r2 score of {lr_big} is {r2_lr_big}')
    
    if r2_lr_big > maxAccu_big:
        maxAccu_big = r2_lr_big
        maxRS_big = i
        print(f"Maximum score of {lr_big} is {r2_lr_big} at Random state {i}")
        print('\n')
# Out:
# ----------------At random State 0 ------------------
# Training score is 0.5021466281623255
# Testing score is 0.4869752914664983
# r2 score of LinearRegression() is 0.4869752914664983
# Maximum score of LinearRegression() is 0.4869752914664983 at Random state 0
#
#
# ----------------At random State 1 ------------------
# Training score is 0.4967176020208749
# Testing score is 0.5093646156676368
# r2 score of LinearRegression() is 0.5093646156676368
# Maximum score of LinearRegression() is 0.5093646156676368 at Random state 1
#
#
# ----------------At random State 2 ------------------
# Training score is 0.49977976921109024
# Testing score is 0.49575377722313474
# r2 score of LinearRegression() is 0.49575377722313474
# ----------------At random State 3 ------------------
# Training score is 0.5044200983645859
# Testing score is 0.4788129130981802
# r2 score of LinearRegression() is 0.4788129130981802
# ----------------At random State 4 ------------------
# Training score is 0.493719839941836
# Testing score is 0.5181134515420379
# r2 score of LinearRegression() is 0.5181134515420379
# Maximum score of LinearRegression() is 0.5181134515420379 at Random state 4
#
#
# ----------------At random State 5 ------------------
# Training score is 0.501309508636008
# Testing score is 0.4886281656675251
# r2 score of LinearRegression() is 0.4886281656675251
# ----------------At random State 6 ------------------
# Training score is 0.5022756847128663
# Testing score is 0.487232393116117
# r2 score of LinearRegression() is 0.487232393116117
# ----------------At random State 7 ------------------
# Training score is 0.5018595772910299
# Testing score is 0.488724832060754
# r2 score of LinearRegression() is 0.488724832060754
# ----------------At random State 8 ------------------
# Training score is 0.5000648312851002
# Testing score is 0.4962067049660186
# r2 score of LinearRegression() is 0.4962067049660186
# ----------------At random State 9 ------------------
# Training score is 0.495214015201659
# Testing score is 0.515659617733019
# r2 score of LinearRegression() is 0.515659617733019
# ----------------At random State 10 ------------------
# Training score is 0.49726689254001044
# Testing score is 0.5069049535027262
# r2 score of LinearRegression() is 0.5069049535027262
# ----------------At random State 11 ------------------
# Training score is 0.4966974477033793
# Testing score is 0.507297961564092
# r2 score of LinearRegression() is 0.507297961564092
# ----------------At random State 12 ------------------
# Training score is 0.5049773470585861
# Testing score is 0.47458871950410775
# r2 score of LinearRegression() is 0.47458871950410775
# ----------------At random State 13 ------------------
# Training score is 0.49774259522274544
# Testing score is 0.5042020084217547
# r2 score of LinearRegression() is 0.5042020084217547
# ----------------At random State 14 ------------------
# Training score is 0.49693545503183445
# Testing score is 0.5066739144614545
# r2 score of LinearRegression() is 0.5066739144614545
# ----------------At random State 15 ------------------
# Training score is 0.49927397797708617
# Testing score is 0.4990054814613957
# r2 score of LinearRegression() is 0.4990054814613957
# ----------------At random State 16 ------------------
# Training score is 0.49825992014593723
# Testing score is 0.5024499961813107
# r2 score of LinearRegression() is 0.5024499961813107
# ----------------At random State 17 ------------------
# Training score is 0.5023465231950794
# Testing score is 0.485899117650203
# r2 score of LinearRegression() is 0.485899117650203
# ----------------At random State 18 ------------------
# Training score is 0.49611388776665666
# Testing score is 0.5122525201061877
# r2 score of LinearRegression() is 0.5122525201061877
# ----------------At random State 19 ------------------
# Training score is 0.506123481247899
# Testing score is 0.47052062494635116
# r2 score of LinearRegression() is 0.47052062494635116
# ----------------At random State 20 ------------------
# Training score is 0.5091836031575034
# Testing score is 0.45842002586054187
# r2 score of LinearRegression() is 0.45842002586054187
# ----------------At random State 21 ------------------
# Training score is 0.49855685727627086
# Testing score is 0.5002460904339008
# r2 score of LinearRegression() is 0.5002460904339008
# ----------------At random State 22 ------------------
# Training score is 0.4990031389656274
# Testing score is 0.49915858963615867
# r2 score of LinearRegression() is 0.49915858963615867
# ----------------At random State 23 ------------------
# Training score is 0.49835729547136753
# Testing score is 0.5026442719514163
# r2 score of LinearRegression() is 0.5026442719514163
# ----------------At random State 24 ------------------
# Training score is 0.4961204032872585
# Testing score is 0.507658995962226
# r2 score of LinearRegression() is 0.507658995962226
# ----------------At random State 25 ------------------
# Training score is 0.5018803991832423
# Testing score is 0.488660474285868
# r2 score of LinearRegression() is 0.488660474285868
# ----------------At random State 26 ------------------
# Training score is 0.49637603946119124
# Testing score is 0.5109802532052123
# r2 score of LinearRegression() is 0.5109802532052123
# ----------------At random State 27 ------------------
# Training score is 0.5008996804767997
# Testing score is 0.4930080614612248
# r2 score of LinearRegression() is 0.4930080614612248
# ----------------At random State 28 ------------------
# Training score is 0.4993687134520537
# Testing score is 0.49907879509546904
# r2 score of LinearRegression() is 0.49907879509546904
# ----------------At random State 29 ------------------
# Training score is 0.49340519577251507
# Testing score is 0.5200846299759472
# r2 score of LinearRegression() is 0.5200846299759472
# Maximum score of LinearRegression() is 0.5200846299759472 at Random state 29
#
#
# ----------------At random State 30 ------------------
# Training score is 0.5062748479535426
# Testing score is 0.4662453486896668
# r2 score of LinearRegression() is 0.4662453486896668
# ----------------At random State 31 ------------------
# Training score is 0.5088876507697114
# Testing score is 0.45960898525372507
# r2 score of LinearRegression() is 0.45960898525372507
# ----------------At random State 32 ------------------
# Training score is 0.49995254040458836
# Testing score is 0.49600056475122123
# r2 score of LinearRegression() is 0.49600056475122123
# ----------------At random State 33 ------------------
# Training score is 0.5038121876509309
# Testing score is 0.48143062879522835
# r2 score of LinearRegression() is 0.48143062879522835
# ----------------At random State 34 ------------------
# Training score is 0.49936088312045024
# Testing score is 0.4983338654772057
# r2 score of LinearRegression() is 0.4983338654772057
# ----------------At random State 35 ------------------
# Training score is 0.49971760717272506
# Testing score is 0.49695696487146357
# r2 score of LinearRegression() is 0.49695696487146357
# ----------------At random State 36 ------------------
# Training score is 0.49661843889494006
# Testing score is 0.5095006173951837
# r2 score of LinearRegression() is 0.5095006173951837
# ----------------At random State 37 ------------------
# Training score is 0.4993954853987691
# Testing score is 0.49781680209626245
# r2 score of LinearRegression() is 0.49781680209626245
# ----------------At random State 38 ------------------
# Training score is 0.49497261348018806
# Testing score is 0.5163188883413293
# r2 score of LinearRegression() is 0.5163188883413293
# ----------------At random State 39 ------------------
# Training score is 0.5036510808409621
# Testing score is 0.4812227411852179
# r2 score of LinearRegression() is 0.4812227411852179
# ----------------At random State 40 ------------------
# Training score is 0.4977715701219849
# Testing score is 0.5050955348517816
# r2 score of LinearRegression() is 0.5050955348517816
# ----------------At random State 41 ------------------
# Training score is 0.5030065464853838
# Testing score is 0.48322438894970077
# r2 score of LinearRegression() is 0.48322438894970077
# ----------------At random State 42 ------------------
# Training score is 0.5003574256564637
# Testing score is 0.4943013951372085
# r2 score of LinearRegression() is 0.4943013951372085
# ----------------At random State 43 ------------------
# Training score is 0.4942901478291153
# Testing score is 0.5178065307367703
# r2 score of LinearRegression() is 0.5178065307367703
# ----------------At random State 44 ------------------
# Training score is 0.49918306888987607
# Testing score is 0.49968265419492197
# r2 score of LinearRegression() is 0.49968265419492197
# ----------------At random State 45 ------------------
# Training score is 0.4998867513327321
# Testing score is 0.4955215406587228
# r2 score of LinearRegression() is 0.4955215406587228
# ----------------At random State 46 ------------------
# Training score is 0.49949668665375824
# Testing score is 0.4952468182947949
# r2 score of LinearRegression() is 0.4952468182947949
# ----------------At random State 47 ------------------
# Training score is 0.49837008384133474
# Testing score is 0.5031882550014994
# r2 score of LinearRegression() is 0.5031882550014994
# ----------------At random State 48 ------------------
# Training score is 0.4952964117424359
# Testing score is 0.5144519267385412
# r2 score of LinearRegression() is 0.5144519267385412
# ----------------At random State 49 ------------------
# Training score is 0.5012671059714803
# Testing score is 0.4906914138304711
# r2 score of LinearRegression() is 0.4906914138304711
# ----------------At random State 50 ------------------
# Training score is 0.49252833379252836
# Testing score is 0.525818800833893
# r2 score of LinearRegression() is 0.525818800833893
# Maximum score of LinearRegression() is 0.525818800833893 at Random state 50
#
#
# ----------------At random State 51 ------------------
# Training score is 0.49680860344117994
# Testing score is 0.5075667144455676
# r2 score of LinearRegression() is 0.5075667144455676
# ----------------At random State 52 ------------------
# Training score is 0.49995009855778405
# Testing score is 0.49665918313797064
# r2 score of LinearRegression() is 0.49665918313797064
# ----------------At random State 53 ------------------
# Training score is 0.5017967276293778
# Testing score is 0.4885158047667304
# r2 score of LinearRegression() is 0.4885158047667304
# ----------------At random State 54 ------------------
# Training score is 0.5018019727845929
# Testing score is 0.48749637061244777
# r2 score of LinearRegression() is 0.48749637061244777
# ----------------At random State 55 ------------------
# Training score is 0.5033258178562658
# Testing score is 0.48163980044129484
# r2 score of LinearRegression() is 0.48163980044129484
# ----------------At random State 56 ------------------
# Training score is 0.4947877128373307
# Testing score is 0.5169376902111984
# r2 score of LinearRegression() is 0.5169376902111984
# ----------------At random State 57 ------------------
# Training score is 0.4990001119986155
# Testing score is 0.500338800172264
# r2 score of LinearRegression() is 0.500338800172264
# ----------------At random State 58 ------------------
# Training score is 0.5019096599128181
# Testing score is 0.489087418141288
# r2 score of LinearRegression() is 0.489087418141288
# ----------------At random State 59 ------------------
# Training score is 0.49282413533903835
# Testing score is 0.5218445690173514
# r2 score of LinearRegression() is 0.5218445690173514
# ----------------At random State 60 ------------------
# Training score is 0.4991139962730565
# Testing score is 0.4983840318315691
# r2 score of LinearRegression() is 0.4983840318315691
# ----------------At random State 61 ------------------
# Training score is 0.4936337353502246
# Testing score is 0.5189611343516576
# r2 score of LinearRegression() is 0.5189611343516576
# ----------------At random State 62 ------------------
# Training score is 0.4953901305885883
# Testing score is 0.5150325933343883
# r2 score of LinearRegression() is 0.5150325933343883
# ----------------At random State 63 ------------------
# Training score is 0.4976100521837665
# Testing score is 0.5054216603912154
# r2 score of LinearRegression() is 0.5054216603912154
# ----------------At random State 64 ------------------
# Training score is 0.5042719016816534
# Testing score is 0.47847552957531625
# r2 score of LinearRegression() is 0.47847552957531625
# ----------------At random State 65 ------------------
# Training score is 0.5083079269268362
# Testing score is 0.46020358272235573
# r2 score of LinearRegression() is 0.46020358272235573
# ----------------At random State 66 ------------------
# Training score is 0.5045574744706536
# Testing score is 0.47785937293846625
# r2 score of LinearRegression() is 0.47785937293846625
# ----------------At random State 67 ------------------
# Training score is 0.5011710012157394
# Testing score is 0.49224609668949926
# r2 score of LinearRegression() is 0.49224609668949926
# ----------------At random State 68 ------------------
# Training score is 0.49494783750278626
# Testing score is 0.5163935432230591
# r2 score of LinearRegression() is 0.5163935432230591
# ----------------At random State 69 ------------------
# Training score is 0.5018439512010766
# Testing score is 0.48797597251459235
# r2 score of LinearRegression() is 0.48797597251459235
# ----------------At random State 70 ------------------
# Training score is 0.4997227935334674
# Testing score is 0.4969979004938818
# r2 score of LinearRegression() is 0.4969979004938818
# ----------------At random State 71 ------------------
# Training score is 0.5056291562114638
# Testing score is 0.4742264884208438
# r2 score of LinearRegression() is 0.4742264884208438
# ----------------At random State 72 ------------------
# Training score is 0.5018024313096081
# Testing score is 0.48882028097658803
# r2 score of LinearRegression() is 0.48882028097658803
# ----------------At random State 73 ------------------
# Training score is 0.4993920465888846
# Testing score is 0.4989681724581697
# r2 score of LinearRegression() is 0.4989681724581697
# ----------------At random State 74 ------------------
# Training score is 0.5046102723990264
# Testing score is 0.4777532650427474
# r2 score of LinearRegression() is 0.4777532650427474
# ----------------At random State 75 ------------------
# Training score is 0.5027979146855065
# Testing score is 0.48506331496516264
# r2 score of LinearRegression() is 0.48506331496516264
# ----------------At random State 76 ------------------
# Training score is 0.4970997001072699
# Testing score is 0.5068894842162045
# r2 score of LinearRegression() is 0.5068894842162045
# ----------------At random State 77 ------------------
# Training score is 0.49499122561364095
# Testing score is 0.5172794950502398
# r2 score of LinearRegression() is 0.5172794950502398
# ----------------At random State 78 ------------------
# Training score is 0.501026591118523
# Testing score is 0.4914036004867912
# r2 score of LinearRegression() is 0.4914036004867912
# ----------------At random State 79 ------------------
# Training score is 0.5015891398301656
# Testing score is 0.4901574536533426
# r2 score of LinearRegression() is 0.4901574536533426
# ----------------At random State 80 ------------------
# Training score is 0.5026253479584928
# Testing score is 0.4842081893566368
# r2 score of LinearRegression() is 0.4842081893566368
# ----------------At random State 81 ------------------
# Training score is 0.49932722212507075
# Testing score is 0.49841581747901753
# r2 score of LinearRegression() is 0.49841581747901753
# ----------------At random State 82 ------------------
# Training score is 0.4895347762003498
# Testing score is 0.5326599611119145
# r2 score of LinearRegression() is 0.5326599611119145
# Maximum score of LinearRegression() is 0.5326599611119145 at Random state 82
#
#
# ----------------At random State 83 ------------------
# Training score is 0.5039171765684378
# Testing score is 0.47892436159327334
# r2 score of LinearRegression() is 0.47892436159327334
# ----------------At random State 84 ------------------
# Training score is 0.5032241569952678
# Testing score is 0.48277281435359476
# r2 score of LinearRegression() is 0.48277281435359476
# ----------------At random State 85 ------------------
# Training score is 0.49832859942856855
# Testing score is 0.5028700620034258
# r2 score of LinearRegression() is 0.5028700620034258
# ----------------At random State 86 ------------------
# Training score is 0.5006145583078498
# Testing score is 0.4932858134608856
# r2 score of LinearRegression() is 0.4932858134608856
# ----------------At random State 87 ------------------
# Training score is 0.5046204013809596
# Testing score is 0.47720946685429433
# r2 score of LinearRegression() is 0.47720946685429433
# ----------------At random State 88 ------------------
# Training score is 0.4966595807401444
# Testing score is 0.5089132402460395
# r2 score of LinearRegression() is 0.5089132402460395
# ----------------At random State 89 ------------------
# Training score is 0.49804115514780367
# Testing score is 0.5036672579854655
# r2 score of LinearRegression() is 0.5036672579854655
# ----------------At random State 90 ------------------
# Training score is 0.4997360462501258
# Testing score is 0.49636580762947935
# r2 score of LinearRegression() is 0.49636580762947935
# ----------------At random State 91 ------------------
# Training score is 0.5017362130911441
# Testing score is 0.4887642209654043
# r2 score of LinearRegression() is 0.4887642209654043
# ----------------At random State 92 ------------------
# Training score is 0.5057210923458226
# Testing score is 0.4706140381883763
# r2 score of LinearRegression() is 0.4706140381883763
# ----------------At random State 93 ------------------
# Training score is 0.5026029480438434
# Testing score is 0.48542087941542356
# r2 score of LinearRegression() is 0.48542087941542356
# ----------------At random State 94 ------------------
# Training score is 0.498468962621634
# Testing score is 0.5021209958611839
# r2 score of LinearRegression() is 0.5021209958611839
# ----------------At random State 95 ------------------
# Training score is 0.49711697924541143
# Testing score is 0.5062662444014581
# r2 score of LinearRegression() is 0.5062662444014581
# ----------------At random State 96 ------------------
# Training score is 0.5070138916492603
# Testing score is 0.46777364144723865
# r2 score of LinearRegression() is 0.46777364144723865
# ----------------At random State 97 ------------------
# Training score is 0.4987776714628439
# Testing score is 0.49985780637851795
# r2 score of LinearRegression() is 0.49985780637851795
# ----------------At random State 98 ------------------
# Training score is 0.5026177515475149
# Testing score is 0.48628380153777595
# r2 score of LinearRegression() is 0.48628380153777595
# ----------------At random State 99 ------------------
# Training score is 0.5045934488954792
# Testing score is 0.47581708733063666
# r2 score of LinearRegression() is 0.47581708733063666
# ----------------At random State 100 ------------------
# Training score is 0.5014153576482345
# Testing score is 0.49060281558561414
# r2 score of LinearRegression() is 0.49060281558561414
# ----------------At random State 101 ------------------
# Training score is 0.4987978526294432
# Testing score is 0.5003927702648798
# r2 score of LinearRegression() is 0.5003927702648798
# ----------------At random State 102 ------------------
# Training score is 0.5066138694828163
# Testing score is 0.46742684817497127
# r2 score of LinearRegression() is 0.46742684817497127
# ----------------At random State 103 ------------------
# Training score is 0.49777855046081765
# Testing score is 0.504262989692942
# r2 score of LinearRegression() is 0.504262989692942
# ----------------At random State 104 ------------------
# Training score is 0.505129286219721
# Testing score is 0.4747661310751379
# r2 score of LinearRegression() is 0.4747661310751379
# ----------------At random State 105 ------------------
# Training score is 0.504271836996129
# Testing score is 0.47732101532001336
# r2 score of LinearRegression() is 0.47732101532001336
# ----------------At random State 106 ------------------
# Training score is 0.5007808651838433
# Testing score is 0.49330585224810186
# r2 score of LinearRegression() is 0.49330585224810186
# ----------------At random State 107 ------------------
# Training score is 0.501788353818855
# Testing score is 0.4890914321783586
# r2 score of LinearRegression() is 0.4890914321783586
# ----------------At random State 108 ------------------
# Training score is 0.5016882265383386
# Testing score is 0.4893431161120635
# r2 score of LinearRegression() is 0.4893431161120635
# ----------------At random State 109 ------------------
# Training score is 0.49564915999222203
# Testing score is 0.5144909421137634
# r2 score of LinearRegression() is 0.5144909421137634
# ----------------At random State 110 ------------------
# Training score is 0.49331797760706864
# Testing score is 0.5236902439429345
# r2 score of LinearRegression() is 0.5236902439429345
# ----------------At random State 111 ------------------
# Training score is 0.5004017766232342
# Testing score is 0.49434930359346163
# r2 score of LinearRegression() is 0.49434930359346163
# ----------------At random State 112 ------------------
# Training score is 0.500511135963505
# Testing score is 0.4943201344522762
# r2 score of LinearRegression() is 0.4943201344522762
# ----------------At random State 113 ------------------
# Training score is 0.49810901600800506
# Testing score is 0.5029490095602986
# r2 score of LinearRegression() is 0.5029490095602986
# ----------------At random State 114 ------------------
# Training score is 0.49788424544508736
# Testing score is 0.5047580508083659
# r2 score of LinearRegression() is 0.5047580508083659
# ----------------At random State 115 ------------------
# Training score is 0.4950783476465975
# Testing score is 0.513308020614035
# r2 score of LinearRegression() is 0.513308020614035
# ----------------At random State 116 ------------------
# Training score is 0.5063899992539378
# Testing score is 0.47134098402597124
# r2 score of LinearRegression() is 0.47134098402597124
# ----------------At random State 117 ------------------
# Training score is 0.5006685147414505
# Testing score is 0.49337963244650673
# r2 score of LinearRegression() is 0.49337963244650673
# ----------------At random State 118 ------------------
# Training score is 0.5036714322854148
# Testing score is 0.4813153592151952
# r2 score of LinearRegression() is 0.4813153592151952
# ----------------At random State 119 ------------------
# Training score is 0.5056210519754127
# Testing score is 0.4740946268486669
# r2 score of LinearRegression() is 0.4740946268486669
# ----------------At random State 120 ------------------
# Training score is 0.49766414762275524
# Testing score is 0.5049357312424618
# r2 score of LinearRegression() is 0.5049357312424618
# ----------------At random State 121 ------------------
# Training score is 0.501595459721184
# Testing score is 0.48873832181233445
# r2 score of LinearRegression() is 0.48873832181233445
# ----------------At random State 122 ------------------
# Training score is 0.4984639152226812
# Testing score is 0.5024988685219963
# r2 score of LinearRegression() is 0.5024988685219963
# ----------------At random State 123 ------------------
# Training score is 0.493122952042479
# Testing score is 0.5200689209476432
# r2 score of LinearRegression() is 0.5200689209476432
# ----------------At random State 124 ------------------
# Training score is 0.5052918467585545
# Testing score is 0.47257010467398264
# r2 score of LinearRegression() is 0.47257010467398264
# ----------------At random State 125 ------------------
# Training score is 0.5015979240575177
# Testing score is 0.489886812035334
# r2 score of LinearRegression() is 0.489886812035334
# ----------------At random State 126 ------------------
# Training score is 0.49616386068411034
# Testing score is 0.5111576674283507
# r2 score of LinearRegression() is 0.5111576674283507
# ----------------At random State 127 ------------------
# Training score is 0.5026943337362821
# Testing score is 0.4859520872345555
# r2 score of LinearRegression() is 0.4859520872345555
# ----------------At random State 128 ------------------
# Training score is 0.4959621792994545
# Testing score is 0.511532150426987
# r2 score of LinearRegression() is 0.511532150426987
# ----------------At random State 129 ------------------
# Training score is 0.5053052907049176
# Testing score is 0.47418938049569037
# r2 score of LinearRegression() is 0.47418938049569037
# ----------------At random State 130 ------------------
# Training score is 0.49608803314092476
# Testing score is 0.5111701604148468
# r2 score of LinearRegression() is 0.5111701604148468
# ----------------At random State 131 ------------------
# Training score is 0.5001701354300125
# Testing score is 0.4954794136082974
# r2 score of LinearRegression() is 0.4954794136082974
# ----------------At random State 132 ------------------
# Training score is 0.4959421672028179
# Testing score is 0.5112844541768413
# r2 score of LinearRegression() is 0.5112844541768413
# ----------------At random State 133 ------------------
# Training score is 0.4940118120804896
# Testing score is 0.5182815942536303
# r2 score of LinearRegression() is 0.5182815942536303
# ----------------At random State 134 ------------------
# Training score is 0.4988185475972946
# Testing score is 0.5007608706100157
# r2 score of LinearRegression() is 0.5007608706100157
# ----------------At random State 135 ------------------
# Training score is 0.49883859547098874
# Testing score is 0.5001504327517582
# r2 score of LinearRegression() is 0.5001504327517582
# ----------------At random State 136 ------------------
# Training score is 0.49329619592775786
# Testing score is 0.520889166446832
# r2 score of LinearRegression() is 0.520889166446832
# ----------------At random State 137 ------------------
# Training score is 0.5040620831658376
# Testing score is 0.4801654249841508
# r2 score of LinearRegression() is 0.4801654249841508
# ----------------At random State 138 ------------------
# Training score is 0.5007977918983961
# Testing score is 0.49188463967516693
# r2 score of LinearRegression() is 0.49188463967516693
# ----------------At random State 139 ------------------
# Training score is 0.49700258793140906
# Testing score is 0.5084652393639981
# r2 score of LinearRegression() is 0.5084652393639981
# ----------------At random State 140 ------------------
# Training score is 0.4990896971467469
# Testing score is 0.4998452837548384
# r2 score of LinearRegression() is 0.4998452837548384
# ----------------At random State 141 ------------------
# Training score is 0.5037733424574229
# Testing score is 0.4795897142308818
# r2 score of LinearRegression() is 0.4795897142308818
# ----------------At random State 142 ------------------
# Training score is 0.4965409622586944
# Testing score is 0.5092406063648043
# r2 score of LinearRegression() is 0.5092406063648043
# ----------------At random State 143 ------------------
# Training score is 0.4975103529961892
# Testing score is 0.5060405572553178
# r2 score of LinearRegression() is 0.5060405572553178
# ----------------At random State 144 ------------------
# Training score is 0.49581915680760424
# Testing score is 0.5120768964101531
# r2 score of LinearRegression() is 0.5120768964101531
# ----------------At random State 145 ------------------
# Training score is 0.5014300840954363
# Testing score is 0.49026162744768065
# r2 score of LinearRegression() is 0.49026162744768065
# ----------------At random State 146 ------------------
# Training score is 0.504515657408882
# Testing score is 0.47841510126445885
# r2 score of LinearRegression() is 0.47841510126445885
# ----------------At random State 147 ------------------
# Training score is 0.49463677677038886
# Testing score is 0.5144526610632523
# r2 score of LinearRegression() is 0.5144526610632523
# ----------------At random State 148 ------------------
# Training score is 0.5010518032282503
# Testing score is 0.49189055362826783
# r2 score of LinearRegression() is 0.49189055362826783
# ----------------At random State 149 ------------------
# Training score is 0.5074380873594092
# Testing score is 0.46634650271472355
# r2 score of LinearRegression() is 0.46634650271472355
# ----------------At random State 150 ------------------
# Training score is 0.500998895533348
# Testing score is 0.49249131375932953
# r2 score of LinearRegression() is 0.49249131375932953
# ----------------At random State 151 ------------------
# Training score is 0.4965901805995987
# Testing score is 0.5094780386222836
# r2 score of LinearRegression() is 0.5094780386222836
# ----------------At random State 152 ------------------
# Training score is 0.4999643684169677
# Testing score is 0.4964971805210423
# r2 score of LinearRegression() is 0.4964971805210423
# ----------------At random State 153 ------------------
# Training score is 0.5001989120989878
# Testing score is 0.4949652343509011
# r2 score of LinearRegression() is 0.4949652343509011
# ----------------At random State 154 ------------------
# Training score is 0.5027436814306295
# Testing score is 0.48488575516597554
# r2 score of LinearRegression() is 0.48488575516597554
# ----------------At random State 155 ------------------
# Training score is 0.502719560334463
# Testing score is 0.4850499411517436
# r2 score of LinearRegression() is 0.4850499411517436
# ----------------At random State 156 ------------------
# Training score is 0.5005860664591851
# Testing score is 0.4935022258761619
# r2 score of LinearRegression() is 0.4935022258761619
# ----------------At random State 157 ------------------
# Training score is 0.4957661634660271
# Testing score is 0.5128756465262894
# r2 score of LinearRegression() is 0.5128756465262894
# ----------------At random State 158 ------------------
# Training score is 0.5024292899419562
# Testing score is 0.4853030367482992
# r2 score of LinearRegression() is 0.4853030367482992
# ----------------At random State 159 ------------------
# Training score is 0.5039623103883268
# Testing score is 0.4786287985994714
# r2 score of LinearRegression() is 0.4786287985994714
# ----------------At random State 160 ------------------
# Training score is 0.5013071811556237
# Testing score is 0.49114193602948397
# r2 score of LinearRegression() is 0.49114193602948397
# ----------------At random State 161 ------------------
# Training score is 0.5068239531773207
# Testing score is 0.4634692388430781
# r2 score of LinearRegression() is 0.4634692388430781
# ----------------At random State 162 ------------------
# Training score is 0.4966837934974223
# Testing score is 0.5085792769222697
# r2 score of LinearRegression() is 0.5085792769222697
# ----------------At random State 163 ------------------
# Training score is 0.49974477082254987
# Testing score is 0.4965498461345669
# r2 score of LinearRegression() is 0.4965498461345669
# ----------------At random State 164 ------------------
# Training score is 0.5019254335207144
# Testing score is 0.48873407433127547
# r2 score of LinearRegression() is 0.48873407433127547
# ----------------At random State 165 ------------------
# Training score is 0.5029731242776192
# Testing score is 0.48281385355525985
# r2 score of LinearRegression() is 0.48281385355525985
# ----------------At random State 166 ------------------
# Training score is 0.5041662904582941
# Testing score is 0.4797311450000299
# r2 score of LinearRegression() is 0.4797311450000299
# ----------------At random State 167 ------------------
# Training score is 0.4940269404837544
# Testing score is 0.5198976501158645
# r2 score of LinearRegression() is 0.5198976501158645
# ----------------At random State 168 ------------------
# Training score is 0.5086926555066105
# Testing score is 0.4586404800903603
# r2 score of LinearRegression() is 0.4586404800903603
# ----------------At random State 169 ------------------
# Training score is 0.4985838430620987
# Testing score is 0.5017924331575006
# r2 score of LinearRegression() is 0.5017924331575006
# ----------------At random State 170 ------------------
# Training score is 0.5050742260873959
# Testing score is 0.4737297824632164
# r2 score of LinearRegression() is 0.4737297824632164
# ----------------At random State 171 ------------------
# Training score is 0.5008468532918334
# Testing score is 0.49113878920490006
# r2 score of LinearRegression() is 0.49113878920490006
# ----------------At random State 172 ------------------
# Training score is 0.4974196054428204
# Testing score is 0.5065353418698391
# r2 score of LinearRegression() is 0.5065353418698391
# ----------------At random State 173 ------------------
# Training score is 0.4984967508654684
# Testing score is 0.5009234095275465
# r2 score of LinearRegression() is 0.5009234095275465
# ----------------At random State 174 ------------------
# Training score is 0.5046440894568728
# Testing score is 0.47591238901493627
# r2 score of LinearRegression() is 0.47591238901493627
# ----------------At random State 175 ------------------
# Training score is 0.5011452102521925
# Testing score is 0.4912977985638851
# r2 score of LinearRegression() is 0.4912977985638851
# ----------------At random State 176 ------------------
# Training score is 0.49968589463000834
# Testing score is 0.49777537096318614
# r2 score of LinearRegression() is 0.49777537096318614
# ----------------At random State 177 ------------------
# Training score is 0.4990442480531422
# Testing score is 0.4990731340766047
# r2 score of LinearRegression() is 0.4990731340766047
# ----------------At random State 178 ------------------
# Training score is 0.5015786935069575
# Testing score is 0.48943958528063414
# r2 score of LinearRegression() is 0.48943958528063414
# ----------------At random State 179 ------------------
# Training score is 0.5058755827790968
# Testing score is 0.47283183678165863
# r2 score of LinearRegression() is 0.47283183678165863
# ----------------At random State 180 ------------------
# Training score is 0.49733944439774436
# Testing score is 0.5064920663913284
# r2 score of LinearRegression() is 0.5064920663913284
# ----------------At random State 181 ------------------
# Training score is 0.5043468514431315
# Testing score is 0.47858950968767044
# r2 score of LinearRegression() is 0.47858950968767044
# ----------------At random State 182 ------------------
# Training score is 0.495929388536962
# Testing score is 0.5107570691570247
# r2 score of LinearRegression() is 0.5107570691570247
# ----------------At random State 183 ------------------
# Training score is 0.4933653282899625
# Testing score is 0.5212405529449364
# r2 score of LinearRegression() is 0.5212405529449364
# ----------------At random State 184 ------------------
# Training score is 0.49921003611264736
# Testing score is 0.4991710619874915
# r2 score of LinearRegression() is 0.4991710619874915
# ----------------At random State 185 ------------------
# Training score is 0.5021809763043833
# Testing score is 0.4869612224030184
# r2 score of LinearRegression() is 0.4869612224030184
# ----------------At random State 186 ------------------
# Training score is 0.5028360333138635
# Testing score is 0.4848627805902139
# r2 score of LinearRegression() is 0.4848627805902139
# ----------------At random State 187 ------------------
# Training score is 0.5010329169249527
# Testing score is 0.49105926544601064
# r2 score of LinearRegression() is 0.49105926544601064
# ----------------At random State 188 ------------------
# Training score is 0.4987669717913865
# Testing score is 0.5011297167706422
# r2 score of LinearRegression() is 0.5011297167706422
# ----------------At random State 189 ------------------
# Training score is 0.49456253060085886
# Testing score is 0.5170951740727038
# r2 score of LinearRegression() is 0.5170951740727038
# ----------------At random State 190 ------------------
# Training score is 0.5017088691974508
# Testing score is 0.48862123967994
# r2 score of LinearRegression() is 0.48862123967994
# ----------------At random State 191 ------------------
# Training score is 0.4950795295411947
# Testing score is 0.5153889606714913
# r2 score of LinearRegression() is 0.5153889606714913
# ----------------At random State 192 ------------------
# Training score is 0.4992824990984299
# Testing score is 0.49861153561010896
# r2 score of LinearRegression() is 0.49861153561010896
# ----------------At random State 193 ------------------
# Training score is 0.5015613642928807
# Testing score is 0.490700623369165
# r2 score of LinearRegression() is 0.490700623369165
# ----------------At random State 194 ------------------
# Training score is 0.5075347326375712
# Testing score is 0.464598490762533
# r2 score of LinearRegression() is 0.464598490762533
# ----------------At random State 195 ------------------
# Training score is 0.5003199905602083
# Testing score is 0.4944733086531896
# r2 score of LinearRegression() is 0.4944733086531896
# ----------------At random State 196 ------------------
# Training score is 0.49666722554229625
# Testing score is 0.5086038224145456
# r2 score of LinearRegression() is 0.5086038224145456
# ----------------At random State 197 ------------------
# Training score is 0.49965898257286756
# Testing score is 0.4972358650199471
# r2 score of LinearRegression() is 0.4972358650199471
# ----------------At random State 198 ------------------
# Training score is 0.5000836436894929
# Testing score is 0.4961933089044057
# r2 score of LinearRegression() is 0.4961933089044057
# ----------------At random State 199 ------------------
# Training score is 0.5001539222976044
# Testing score is 0.49505117783655017
# r2 score of LinearRegression() is 0.49505117783655017
# ----------------At random State 200 ------------------
# Training score is 0.4950113131965398
# Testing score is 0.5138888192846653
# r2 score of LinearRegression() is 0.5138888192846653
# ----------------At random State 201 ------------------
# Training score is 0.5031895119948764
# Testing score is 0.4834984839589329
# r2 score of LinearRegression() is 0.4834984839589329
# ----------------At random State 202 ------------------
# Training score is 0.4970538366881945
# Testing score is 0.5077185797218393
# r2 score of LinearRegression() is 0.5077185797218393
# ----------------At random State 203 ------------------
# Training score is 0.49722446359949823
# Testing score is 0.5056463706938419
# r2 score of LinearRegression() is 0.5056463706938419
# ----------------At random State 204 ------------------
# Training score is 0.5003248707898786
# Testing score is 0.4952347803845899
# r2 score of LinearRegression() is 0.4952347803845899
# ----------------At random State 205 ------------------
# Training score is 0.4993997581231995
# Testing score is 0.49860221657301373
# r2 score of LinearRegression() is 0.49860221657301373
# ----------------At random State 206 ------------------
# Training score is 0.4945986345343223
# Testing score is 0.5150322903360436
# r2 score of LinearRegression() is 0.5150322903360436
# ----------------At random State 207 ------------------
# Training score is 0.4960349818857953
# Testing score is 0.512757726124627
# r2 score of LinearRegression() is 0.512757726124627
# ----------------At random State 208 ------------------
# Training score is 0.5038968936196906
# Testing score is 0.4793358127551546
# r2 score of LinearRegression() is 0.4793358127551546
# ----------------At random State 209 ------------------
# Training score is 0.49412512967723743
# Testing score is 0.5183675222816028
# r2 score of LinearRegression() is 0.5183675222816028
# ----------------At random State 210 ------------------
# Training score is 0.5025568813622566
# Testing score is 0.48588729950866727
# r2 score of LinearRegression() is 0.48588729950866727
# ----------------At random State 211 ------------------
# Training score is 0.505438447796253
# Testing score is 0.4747507317439813
# r2 score of LinearRegression() is 0.4747507317439813
# ----------------At random State 212 ------------------
# Training score is 0.5044299831444193
# Testing score is 0.4760282194857115
# r2 score of LinearRegression() is 0.4760282194857115
# ----------------At random State 213 ------------------
# Training score is 0.49991017779909386
# Testing score is 0.49655304941835754
# r2 score of LinearRegression() is 0.49655304941835754
# ----------------At random State 214 ------------------
# Training score is 0.502684820969401
# Testing score is 0.48508694260455276
# r2 score of LinearRegression() is 0.48508694260455276
# ----------------At random State 215 ------------------
# Training score is 0.5056608358118555
# Testing score is 0.4717201104366915
# r2 score of LinearRegression() is 0.4717201104366915
# ----------------At random State 216 ------------------
# Training score is 0.5016845295227872
# Testing score is 0.4901574533663925
# r2 score of LinearRegression() is 0.4901574533663925
# ----------------At random State 217 ------------------
# Training score is 0.5001435388334099
# Testing score is 0.49613254273898755
# r2 score of LinearRegression() is 0.49613254273898755
# ----------------At random State 218 ------------------
# Training score is 0.5031615971156068
# Testing score is 0.4835049436386678
# r2 score of LinearRegression() is 0.4835049436386678
# ----------------At random State 219 ------------------
# Training score is 0.5033381082776492
# Testing score is 0.4824010609775501
# r2 score of LinearRegression() is 0.4824010609775501
# ----------------At random State 220 ------------------
# Training score is 0.4965333968216217
# Testing score is 0.5107719415471952
# r2 score of LinearRegression() is 0.5107719415471952
# ----------------At random State 221 ------------------
# Training score is 0.49503092605997623
# Testing score is 0.516485881392955
# r2 score of LinearRegression() is 0.516485881392955
# ----------------At random State 222 ------------------
# Training score is 0.5049334102025815
# Testing score is 0.4752006512016812
# r2 score of LinearRegression() is 0.4752006512016812
# ----------------At random State 223 ------------------
# Training score is 0.49999606974319255
# Testing score is 0.49575930567381976
# r2 score of LinearRegression() is 0.49575930567381976
# ----------------At random State 224 ------------------
# Training score is 0.49708915305608803
# Testing score is 0.5081136686665423
# r2 score of LinearRegression() is 0.5081136686665423
# ----------------At random State 225 ------------------
# Training score is 0.5069339882343904
# Testing score is 0.4678389869965619
# r2 score of LinearRegression() is 0.4678389869965619
# ----------------At random State 226 ------------------
# Training score is 0.497837655783816
# Testing score is 0.5038418682259438
# r2 score of LinearRegression() is 0.5038418682259438
# ----------------At random State 227 ------------------
# Training score is 0.4992778637382309
# Testing score is 0.4985797629689913
# r2 score of LinearRegression() is 0.4985797629689913
# ----------------At random State 228 ------------------
# Training score is 0.50022058323994
# Testing score is 0.49467438534507824
# r2 score of LinearRegression() is 0.49467438534507824
# ----------------At random State 229 ------------------
# Training score is 0.49938460236274484
# Testing score is 0.49853116843691414
# r2 score of LinearRegression() is 0.49853116843691414
# ----------------At random State 230 ------------------
# Training score is 0.5061464177131831
# Testing score is 0.4694526326665327
# r2 score of LinearRegression() is 0.4694526326665327
# ----------------At random State 231 ------------------
# Training score is 0.4979790092096721
# Testing score is 0.5046589715074536
# r2 score of LinearRegression() is 0.5046589715074536
# ----------------At random State 232 ------------------
# Training score is 0.5033819172894697
# Testing score is 0.4818524879584043
# r2 score of LinearRegression() is 0.4818524879584043
# ----------------At random State 233 ------------------
# Training score is 0.5061022571076322
# Testing score is 0.4689087520257582
# r2 score of LinearRegression() is 0.4689087520257582
# ----------------At random State 234 ------------------
# Training score is 0.49442009783721674
# Testing score is 0.5172616671390932
# r2 score of LinearRegression() is 0.5172616671390932
# ----------------At random State 235 ------------------
# Training score is 0.4992956302661955
# Testing score is 0.49910549089779344
# r2 score of LinearRegression() is 0.49910549089779344
# ----------------At random State 236 ------------------
# Training score is 0.49388243256669695
# Testing score is 0.5194103254959457
# r2 score of LinearRegression() is 0.5194103254959457
# ----------------At random State 237 ------------------
# Training score is 0.4978805324257042
# Testing score is 0.5038279129851613
# r2 score of LinearRegression() is 0.5038279129851613
# ----------------At random State 238 ------------------
# Training score is 0.4979564094930572
# Testing score is 0.5042051841149465
# r2 score of LinearRegression() is 0.5042051841149465
# ----------------At random State 239 ------------------
# Training score is 0.5036284292176358
# Testing score is 0.4824422709536539
# r2 score of LinearRegression() is 0.4824422709536539
# ----------------At random State 240 ------------------
# Training score is 0.49666822607254324
# Testing score is 0.5093622811053768
# r2 score of LinearRegression() is 0.5093622811053768
# ----------------At random State 241 ------------------
# Training score is 0.49668599086901943
# Testing score is 0.5093412855593074
# r2 score of LinearRegression() is 0.5093412855593074
# ----------------At random State 242 ------------------
# Training score is 0.498051528764593
# Testing score is 0.5044001756944074
# r2 score of LinearRegression() is 0.5044001756944074
# ----------------At random State 243 ------------------
# Training score is 0.4951060879626429
# Testing score is 0.5155125036950317
# r2 score of LinearRegression() is 0.5155125036950317
# ----------------At random State 244 ------------------
# Training score is 0.5109564263925089
# Testing score is 0.4494444314786198
# r2 score of LinearRegression() is 0.4494444314786198
# ----------------At random State 245 ------------------
# Training score is 0.5056422115034879
# Testing score is 0.47263618633066495
# r2 score of LinearRegression() is 0.47263618633066495
# ----------------At random State 246 ------------------
# Training score is 0.4960867063009585
# Testing score is 0.5122077047168778
# r2 score of LinearRegression() is 0.5122077047168778
# ----------------At random State 247 ------------------
# Training score is 0.49539798646150457
# Testing score is 0.5150086466851873
# r2 score of LinearRegression() is 0.5150086466851873
# ----------------At random State 248 ------------------
# Training score is 0.4959777038110442
# Testing score is 0.5109120247884389
# r2 score of LinearRegression() is 0.5109120247884389
# ----------------At random State 249 ------------------
# Training score is 0.49990667868423844
# Testing score is 0.49683006765800564
# r2 score of LinearRegression() is 0.49683006765800564
# ----------------At random State 250 ------------------
# Training score is 0.5051594143605282
# Testing score is 0.4759593642856428
# r2 score of LinearRegression() is 0.4759593642856428
# ----------------At random State 251 ------------------
# Training score is 0.5014142059573987
# Testing score is 0.48970349883188957
# r2 score of LinearRegression() is 0.48970349883188957
# ----------------At random State 252 ------------------
# Training score is 0.5038622912847746
# Testing score is 0.4795325583332434
# r2 score of LinearRegression() is 0.4795325583332434
# ----------------At random State 253 ------------------
# Training score is 0.4991831037731985
# Testing score is 0.4991195549638411
# r2 score of LinearRegression() is 0.4991195549638411
# ----------------At random State 254 ------------------
# Training score is 0.4939756570623346
# Testing score is 0.5180149347480743
# r2 score of LinearRegression() is 0.5180149347480743
# ----------------At random State 255 ------------------
# Training score is 0.49778333005396125
# Testing score is 0.5058039625776747
# r2 score of LinearRegression() is 0.5058039625776747
# ----------------At random State 256 ------------------
# Training score is 0.49769020504011363
# Testing score is 0.502028385271247
# r2 score of LinearRegression() is 0.502028385271247
# ----------------At random State 257 ------------------
# Training score is 0.49905565547960873
# Testing score is 0.5004772908435575
# r2 score of LinearRegression() is 0.5004772908435575
# ----------------At random State 258 ------------------
# Training score is 0.49585601537242596
# Testing score is 0.5130973975830462
# r2 score of LinearRegression() is 0.5130973975830462
# ----------------At random State 259 ------------------
# Training score is 0.49893062332529137
# Testing score is 0.5006955743093009
# r2 score of LinearRegression() is 0.5006955743093009
# ----------------At random State 260 ------------------
# Training score is 0.49808777627755585
# Testing score is 0.5043035599854873
# r2 score of LinearRegression() is 0.5043035599854873
# ----------------At random State 261 ------------------
# Training score is 0.4993453117801411
# Testing score is 0.49915606009770674
# r2 score of LinearRegression() is 0.49915606009770674
# ----------------At random State 262 ------------------
# ...
# ----------------At random State 412 ------------------
# Training score is 0.4960602646108774
# Testing score is 0.5113965244082261
# r2 score of LinearRegression() is 0.5113965244082261
# ----------------At random State 413 ------------------
# Training score is 0.49326277948938846
# Testing score is 0.5243009191564043
# r2 score of LinearRegression() is 0.5243009191564043
# ----------------At random State 414 ------------------
# Training score is 0.5034091904428766
# Testing score is 0.482541347800713
# r2 score of LinearRegression() is 0.482541347800713
# ----------------At random State 415 ------------------
# Training score is 0.49541820735231834
# Testing score is 0.5145318760438399
# r2 score of LinearRegression() is 0.5145318760438399
# ----------------At random State 416 ------------------
# Training score is 0.4933185401340403
# Testing score is 0.5205610966165786
# r2 score of LinearRegression() is 0.5205610966165786
# ----------------At random State 417 ------------------
# Training score is 0.5000104365193514
# Testing score is 0.49578656872656124
# r2 score of LinearRegression() is 0.49578656872656124
# ----------------At random State 418 ------------------
# Training score is 0.4999255258640254
# Testing score is 0.49600043180302744
# r2 score of LinearRegression() is 0.49600043180302744
# ----------------At random State 419 ------------------
# Training score is 0.5009637171806334
# Testing score is 0.49058564980580244
# r2 score of LinearRegression() is 0.49058564980580244
# ----------------At random State 420 ------------------
# Training score is 0.5061615696745074
# Testing score is 0.4704121028691439
# r2 score of LinearRegression() is 0.4704121028691439
# ----------------At random State 421 ------------------
# Training score is 0.5014906542803841
# Testing score is 0.4903480055695252
# r2 score of LinearRegression() is 0.4903480055695252
# ----------------At random State 422 ------------------
# Training score is 0.5013172148958658
# Testing score is 0.4890905993941814
# r2 score of LinearRegression() is 0.4890905993941814
# ----------------At random State 423 ------------------
# Training score is 0.5054365637093642
# Testing score is 0.47169594796216996
# r2 score of LinearRegression() is 0.47169594796216996
# ----------------At random State 424 ------------------
# Training score is 0.49932467942627445
# Testing score is 0.498617251311388
# r2 score of LinearRegression() is 0.498617251311388
# ----------------At random State 425 ------------------
# Training score is 0.5071525221080959
# Testing score is 0.4655726486795462
# r2 score of LinearRegression() is 0.4655726486795462
# ----------------At random State 426 ------------------
# Training score is 0.5026487340925367
# Testing score is 0.4856297274347018
# r2 score of LinearRegression() is 0.4856297274347018
# ----------------At random State 427 ------------------
# Training score is 0.49609175370063807
# Testing score is 0.5116717720784025
# r2 score of LinearRegression() is 0.5116717720784025
# ----------------At random State 428 ------------------
# Training score is 0.4989886082659578
# Testing score is 0.5000790814390705
# r2 score of LinearRegression() is 0.5000790814390705
# ----------------At random State 429 ------------------
# Training score is 0.5014837804126144
# Testing score is 0.4904074193096013
# r2 score of LinearRegression() is 0.4904074193096013
# ----------------At random State 430 ------------------
# Training score is 0.49951220805205787
# Testing score is 0.49752970576260713
# r2 score of LinearRegression() is 0.49752970576260713
# ----------------At random State 431 ------------------
# Training score is 0.49975566757721224
# Testing score is 0.49667243896086577
# r2 score of LinearRegression() is 0.49667243896086577
# ----------------At random State 432 ------------------
# Training score is 0.49768077640092034
# Testing score is 0.5051124890369989
# r2 score of LinearRegression() is 0.5051124890369989
# ----------------At random State 433 ------------------
# Training score is 0.4984325231126482
# Testing score is 0.5025714203674543
# r2 score of LinearRegression() is 0.5025714203674543
# ----------------At random State 434 ------------------
# Training score is 0.4969731592444713
# Testing score is 0.5086223734417159
# r2 score of LinearRegression() is 0.5086223734417159
# ----------------At random State 435 ------------------
# Training score is 0.49791110436532726
# Testing score is 0.5044276287179126
# r2 score of LinearRegression() is 0.5044276287179126
# ----------------At random State 436 ------------------
# Training score is 0.4918349186945097
# Testing score is 0.5264680734320488
# r2 score of LinearRegression() is 0.5264680734320488
# ----------------At random State 437 ------------------
# Training score is 0.49796827721817516
# Testing score is 0.5037612487097249
# r2 score of LinearRegression() is 0.5037612487097249
# ----------------At random State 438 ------------------
# Training score is 0.502937248853189
# Testing score is 0.4849156681215505
# r2 score of LinearRegression() is 0.4849156681215505
# ----------------At random State 439 ------------------
# Training score is 0.49783655796217663
# Testing score is 0.5055141754901029
# r2 score of LinearRegression() is 0.5055141754901029
# ----------------At random State 440 ------------------
# Training score is 0.5029798357834665
# Testing score is 0.48401523885219755
# r2 score of LinearRegression() is 0.48401523885219755
# ----------------At random State 441 ------------------
# Training score is 0.5036215967271214
# Testing score is 0.48180292369703037
# r2 score of LinearRegression() is 0.48180292369703037
# ----------------At random State 442 ------------------
# Training score is 0.5002911649001898
# Testing score is 0.49423899905226953
# r2 score of LinearRegression() is 0.49423899905226953
# ----------------At random State 443 ------------------
# Training score is 0.49848636347933084
# Testing score is 0.5028237969977276
# r2 score of LinearRegression() is 0.5028237969977276
# ----------------At random State 444 ------------------
# Training score is 0.5017746519998705
# Testing score is 0.4885159568108546
# r2 score of LinearRegression() is 0.4885159568108546
# ----------------At random State 445 ------------------
# Training score is 0.5013998284660026
# Testing score is 0.4892991872160385
# r2 score of LinearRegression() is 0.4892991872160385
# ----------------At random State 446 ------------------
# Training score is 0.5021931164695295
# Testing score is 0.485998456541726
# r2 score of LinearRegression() is 0.485998456541726
# ----------------At random State 447 ------------------
# Training score is 0.5003434164713823
# Testing score is 0.49428070432339166
# r2 score of LinearRegression() is 0.49428070432339166
# ----------------At random State 448 ------------------
# Training score is 0.501750681322441
# Testing score is 0.48869819913265133
# r2 score of LinearRegression() is 0.48869819913265133
# ----------------At random State 449 ------------------
# Training score is 0.5053162300771799
# Testing score is 0.47403617058075753
# r2 score of LinearRegression() is 0.47403617058075753
# ----------------At random State 450 ------------------
# Training score is 0.4941895867827497
# Testing score is 0.5197779947722512
# r2 score of LinearRegression() is 0.5197779947722512
# ----------------At random State 451 ------------------
# Training score is 0.5001005050819416
# Testing score is 0.49571501148597596
# r2 score of LinearRegression() is 0.49571501148597596
# ----------------At random State 452 ------------------
# Training score is 0.5025445940000073
# Testing score is 0.4861003683754047
# r2 score of LinearRegression() is 0.4861003683754047
# ----------------At random State 453 ------------------
# Training score is 0.499635787053726
# Testing score is 0.4978105773824554
# r2 score of LinearRegression() is 0.4978105773824554
# ----------------At random State 454 ------------------
# Training score is 0.4981983606493421
# Testing score is 0.5031317446154076
# r2 score of LinearRegression() is 0.5031317446154076
# ----------------At random State 455 ------------------
# Training score is 0.5043986899285133
# Testing score is 0.47710911198252026
# r2 score of LinearRegression() is 0.47710911198252026
# ----------------At random State 456 ------------------
# Training score is 0.4931201531443774
# Testing score is 0.5248060739390192
# r2 score of LinearRegression() is 0.5248060739390192
# ----------------At random State 457 ------------------
# Training score is 0.5016645620106757
# Testing score is 0.4892783914761353
# r2 score of LinearRegression() is 0.4892783914761353
# ----------------At random State 458 ------------------
# Training score is 0.49877692824013664
# Testing score is 0.5005802028957884
# r2 score of LinearRegression() is 0.5005802028957884
# ----------------At random State 459 ------------------
# Training score is 0.4963254872229267
# Testing score is 0.5109876216963738
# r2 score of LinearRegression() is 0.5109876216963738
# ----------------At random State 460 ------------------
# Training score is 0.5012956909722099
# Testing score is 0.4897081117637988
# r2 score of LinearRegression() is 0.4897081117637988
# ----------------At random State 461 ------------------
# Training score is 0.49718627466694
# Testing score is 0.5070124738674218
# r2 score of LinearRegression() is 0.5070124738674218
# ----------------At random State 462 ------------------
# Training score is 0.5017170433660183
# Testing score is 0.4876894066099847
# r2 score of LinearRegression() is 0.4876894066099847
# ----------------At random State 463 ------------------
# Training score is 0.4949005373901427
# Testing score is 0.5150200540347808
# r2 score of LinearRegression() is 0.5150200540347808
# ----------------At random State 464 ------------------
# Training score is 0.49721216076510855
# Testing score is 0.5076086784261638
# r2 score of LinearRegression() is 0.5076086784261638
# ----------------At random State 465 ------------------
# Training score is 0.4995828235990719
# Testing score is 0.49837362135459784
# r2 score of LinearRegression() is 0.49837362135459784
# ----------------At random State 466 ------------------
# Training score is 0.49855735379656296
# Testing score is 0.5022983481846932
# r2 score of LinearRegression() is 0.5022983481846932
# ----------------At random State 467 ------------------
# Training score is 0.4997795018824863
# Testing score is 0.4964589050721331
# r2 score of LinearRegression() is 0.4964589050721331
# ----------------At random State 468 ------------------
# Training score is 0.4975371378466935
# Testing score is 0.5035802539667665
# r2 score of LinearRegression() is 0.5035802539667665
# ----------------At random State 469 ------------------
# Training score is 0.49479336596724155
# Testing score is 0.5141808758659431
# r2 score of LinearRegression() is 0.5141808758659431
# ----------------At random State 470 ------------------
# Training score is 0.5054709438800016
# Testing score is 0.473291261120545
# r2 score of LinearRegression() is 0.473291261120545
# ----------------At random State 471 ------------------
# Training score is 0.5006199653434102
# Testing score is 0.4940568071997441
# r2 score of LinearRegression() is 0.4940568071997441
# ----------------At random State 472 ------------------
# Training score is 0.49802573350328627
# Testing score is 0.5033757923121616
# r2 score of LinearRegression() is 0.5033757923121616
# ----------------At random State 473 ------------------
# Training score is 0.494537256355454
# Testing score is 0.5170461169564875
# r2 score of LinearRegression() is 0.5170461169564875
# ----------------At random State 474 ------------------
# Training score is 0.4986182049161749
# Testing score is 0.50226286165301
# r2 score of LinearRegression() is 0.50226286165301
# ----------------At random State 475 ------------------
# Training score is 0.49885557652837853
# Testing score is 0.5009255030301092
# r2 score of LinearRegression() is 0.5009255030301092
# ----------------At random State 476 ------------------
# Training score is 0.5011397063049872
# Testing score is 0.49065265042533235
# r2 score of LinearRegression() is 0.49065265042533235
# ----------------At random State 477 ------------------
# Training score is 0.5023073755868879
# Testing score is 0.4865255029226284
# r2 score of LinearRegression() is 0.4865255029226284
# ----------------At random State 478 ------------------
# Training score is 0.5011496007317584
# Testing score is 0.49169447849460135
# r2 score of LinearRegression() is 0.49169447849460135
# ----------------At random State 479 ------------------
# Training score is 0.5020875152729718
# Testing score is 0.48697073279616343
# r2 score of LinearRegression() is 0.48697073279616343
# ----------------At random State 480 ------------------
# Training score is 0.49590506995190486
# Testing score is 0.5126987133892712
# r2 score of LinearRegression() is 0.5126987133892712
# ----------------At random State 481 ------------------
# Training score is 0.5033509904336948
# Testing score is 0.4830027718800034
# r2 score of LinearRegression() is 0.4830027718800034
# ----------------At random State 482 ------------------
# Training score is 0.4933202553622894
# Testing score is 0.5219834205477091
# r2 score of LinearRegression() is 0.5219834205477091
# ----------------At random State 483 ------------------
# Training score is 0.49600662129515816
# Testing score is 0.511214803484386
# r2 score of LinearRegression() is 0.511214803484386
# ----------------At random State 484 ------------------
# Training score is 0.49786181338332713
# Testing score is 0.5034206937578696
# r2 score of LinearRegression() is 0.5034206937578696
# ----------------At random State 485 ------------------
# Training score is 0.4991971989842423
# Testing score is 0.4994463168672121
# r2 score of LinearRegression() is 0.4994463168672121
# ----------------At random State 486 ------------------
# Training score is 0.4945170232977021
# Testing score is 0.5189505953256832
# r2 score of LinearRegression() is 0.5189505953256832
# ----------------At random State 487 ------------------
# Training score is 0.49369971452492223
# Testing score is 0.5210583194460079
# r2 score of LinearRegression() is 0.5210583194460079
# ----------------At random State 488 ------------------
# Training score is 0.5073732519069146
# Testing score is 0.4671561730529389
# r2 score of LinearRegression() is 0.4671561730529389
# ----------------At random State 489 ------------------
# Training score is 0.4994635646990123
# Testing score is 0.4976218442417263
# r2 score of LinearRegression() is 0.4976218442417263
# ----------------At random State 490 ------------------
# Training score is 0.49980743084242163
# Testing score is 0.4968943185352851
# r2 score of LinearRegression() is 0.4968943185352851
# ----------------At random State 491 ------------------
# Training score is 0.50042919736016
# Testing score is 0.49484818356211124
# r2 score of LinearRegression() is 0.49484818356211124
# ----------------At random State 492 ------------------
# Training score is 0.50212207843189
# Testing score is 0.48652487806875255
# r2 score of LinearRegression() is 0.48652487806875255
# ----------------At random State 493 ------------------
# Training score is 0.5016695114939451
# Testing score is 0.48907162141380867
# r2 score of LinearRegression() is 0.48907162141380867
# ----------------At random State 494 ------------------
# Training score is 0.5068872026745493
# Testing score is 0.4643024074253176
# r2 score of LinearRegression() is 0.4643024074253176
# ----------------At random State 495 ------------------
# Training score is 0.49624413334105955
# Testing score is 0.5102364295673534
# r2 score of LinearRegression() is 0.5102364295673534
# ----------------At random State 496 ------------------
# Training score is 0.49830585603444677
# Testing score is 0.503334646092561
# r2 score of LinearRegression() is 0.503334646092561
# ----------------At random State 497 ------------------
# Training score is 0.4976245197113994
# Testing score is 0.5059136845181109
# r2 score of LinearRegression() is 0.5059136845181109
# ----------------At random State 498 ------------------
# Training score is 0.5038850092395366
# Testing score is 0.4807343534855435
# r2 score of LinearRegression() is 0.4807343534855435
# ----------------At random State 499 ------------------
# Training score is 0.5020123735156905
# Testing score is 0.4861410477206547
# r2 score of LinearRegression() is 0.4861410477206547

# %%
algm_big = [lr_big, dtr_big, knr_big, svr_big, rfr_big]

for m in algm_big:
    x_train, x_test,y_train, y_test = train_test_split(X,y, random_state=327, test_size=0.20)
    m.fit(x_train, y_train)
    pred_big =m.predict(x_test)
    print(f'----------------------Model results for {m} ------------------------')
    print(f'Score of {m} is {m.score(x_train, y_train)}')
    print(f'Testing Score of {m} is {m.score(x_test, y_test)}')
    print(f"R2 Score of {m} is  {r2_score(y_test, pred_big)}")
    print(f"Mean Squared error of {m} is {mean_squared_error(y_test, pred_big)}")
    print(f"Root Mean Squared error of {m} is {np.sqrt(mean_squared_error(y_test, pred_big))}")
    print('\n')
# Out:
# ----------------------Model results for LinearRegression() ------------------------
# Score of LinearRegression() is 0.48736411869584284
# Testing Score of LinearRegression() is 0.5428328978510741
# R2 Score of LinearRegression() is  0.5428328978510741
# Mean Squared error of LinearRegression() is 1205789.2923987946
# Root Mean Squared error of LinearRegression() is 1098.084373988991
#
#
# ----------------------Model results for DecisionTreeRegressor() ------------------------
# Score of DecisionTreeRegressor() is 1.0
# Testing Score of DecisionTreeRegressor() is 0.19584505948652042
# R2 Score of DecisionTreeRegressor() is  0.19584505948652042
# Mean Squared error of DecisionTreeRegressor() is 2120978.1109421887
# Root Mean Squared error of DecisionTreeRegressor() is 1456.3578237995594
#
#
# ----------------------Model results for KNeighborsRegressor() ------------------------
# Score of KNeighborsRegressor() is 0.6615469400422003
# Testing Score of KNeighborsRegressor() is 0.5288010244321256
# R2 Score of KNeighborsRegressor() is  0.5288010244321256
# Mean Squared error of KNeighborsRegressor() is 1242798.6980216687
# Root Mean Squared error of KNeighborsRegressor() is 1114.8088168029838
#
#
# ----------------------Model results for SVR() ------------------------
# Score of SVR() is 0.05142827972470665
# Testing Score of SVR() is 0.061942227030469144
# R2 Score of SVR() is  0.061942227030469144
# Mean Squared error of SVR() is 2474150.071125754
# Root Mean Squared error of SVR() is 1572.9431239322528
#
#
# ----------------------Model results for RandomForestRegressor() ------------------------
# Score of RandomForestRegressor() is 0.9340986400680852
# Testing Score of RandomForestRegressor() is 0.5737630233726372
# R2 Score of RandomForestRegressor() is  0.5737630233726372
# Mean Squared error of RandomForestRegressor() is 1124210.338027091
# Root Mean Squared error of RandomForestRegressor() is 1060.287856210327

# %% [markdown]
# - Random Forest Regressor is giving the best results

# %% [markdown]
# #### Cross Validation of Each Model

# %%
# Before checking all the models we will identify best 'cv' value using Linear Regression 
from sklearn.model_selection import cross_val_score
max_cvscore_big = 0 
max_cv_big = 0
for j in range(2,15):
    cv_score_big = cross_val_score(lr_big, X,y,cv=j)
    cv_mean_big = cv_score_big.mean()
    print(f"At cross fold {j} the cv score is {cv_mean_big}")
    print('\n') 
    
    if cv_mean_big > max_cvscore_big:
        max_cvscore_big = cv_mean_big
        max_cv_big = j
        print(f"At cross fold {j} the Maximum CV score is {max_cvscore_big}")
# Out:
# At cross fold 2 the cv score is 0.49705970251440573
#
#
# At cross fold 2 the Maximum CV score is 0.49705970251440573
# At cross fold 3 the cv score is 0.4972917110675302
#
#
# At cross fold 3 the Maximum CV score is 0.4972917110675302
# At cross fold 4 the cv score is 0.4960868074513225
#
#
# At cross fold 5 the cv score is 0.49707887918177607
#
#
# At cross fold 6 the cv score is 0.4975057897739192
#
#
# At cross fold 6 the Maximum CV score is 0.4975057897739192
# At cross fold 7 the cv score is 0.49767723225958116
#
#
# At cross fold 7 the Maximum CV score is 0.49767723225958116
# At cross fold 8 the cv score is 0.4970286097728379
#
#
# At cross fold 9 the cv score is 0.4972595799074527
#
#
# At cross fold 10 the cv score is 0.49724812611072966
#
#
# At cross fold 11 the cv score is 0.49734171189550486
#
#
# At cross fold 12 the cv score is 0.49700175969283816
#
#
# At cross fold 13 the cv score is 0.49598677801942187
#
#
# At cross fold 14 the cv score is 0.49653642924962427

# %%
# Using cross validation for all the models
# algm_big is a list containing the instance of all the models

for m_cv in algm_big:
    cv_score = cross_val_score(m_cv,X,y,cv=7)
    cv_mean = cv_score.mean()
    print('---------------------------------------------------')
    print(f"The cross validation score is {cv_mean} for {m_cv}")
    print('\n')
# Out:
# ---------------------------------------------------
# The cross validation score is 0.49767723225958116 for LinearRegression()
#
#
# ---------------------------------------------------
# The cross validation score is 0.12433478576163368 for DecisionTreeRegressor()
#
#
# ---------------------------------------------------
# The cross validation score is 0.4970083562312227 for KNeighborsRegressor()
#
#
# ---------------------------------------------------
# The cross validation score is 0.05842125046547649 for SVR()
#
#
# ---------------------------------------------------
# The cross validation score is 0.5417029222622557 for RandomForestRegressor()

# %% [markdown]
# ##### Before pickling using the test data

# %%
df_test = pd.read_csv(r'E:\Datasets\bigdatamart_rep-master\bigdatamart_rep-master\bigdatamart_Test.csv')
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
#Checking null values in test data
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
item_weight_mean = df_test.groupby('Item_Type')
item_weight_mean.mean()['Item_Weight']
# Out:
# Item_Type
# Baking Goods             12.272418
# Breads                   10.866799
# Breakfast                13.759603
# Canned                   12.393565
# Dairy                    12.955040
# Frozen Foods             12.101543
# Fruits and Vegetables    13.146659
# Hard Drinks              11.844417
# Health and Hygiene       13.216929
# Household                13.270504
# Meat                     12.702148
# Others                   14.009725
# Seafood                  13.241136
# Snack Foods              12.684256
# Soft Drinks              11.691965
# Starchy Foods            13.618247
# Name: Item_Weight, dtype: float64

# %%
df_test['Item_Weight'].fillna(df_test.groupby('Item_Type')['Item_Weight'].transform('mean'), inplace = True)

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58     20.75000          Low Fat         0.007565  Snack Foods
# 1           FDW14      8.30000              reg         0.038428        Dairy
# 2           NCN55     14.60000          Low Fat         0.099575       Others
# 3           FDQ58      7.31500          Low Fat         0.015388  Snack Foods
# 4           FDY38     12.95504          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0], inplace=True)

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58     20.75000          Low Fat         0.007565  Snack Foods
# 1           FDW14      8.30000              reg         0.038428        Dairy
# 2           NCN55     14.60000          Low Fat         0.099575       Others
# 3           FDQ58      7.31500          Low Fat         0.015388  Snack Foods
# 4           FDY38     12.95504          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df_test["Item_Fat_Content"].replace("low fat","Low Fat",inplace=True)
df_test["Item_Fat_Content"].replace("LF","Low Fat",inplace=True)
df_test["Item_Fat_Content"].replace("reg","Regular",inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                5681 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                5681 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
sns.countplot(df_test['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
# Label Encoding
df_test['Item_Identifier']=le.fit_transform(df_test['Item_Identifier'])
df_test['Item_Fat_Content']=le.fit_transform(df_test['Item_Fat_Content'])
df_test['Item_Type']=le.fit_transform(df_test['Item_Type'])
df_test['Outlet_Identifier']=le.fit_transform(df_test['Outlet_Identifier'])
df_test['Outlet_Size']=le.fit_transform(df_test['Outlet_Size'])
df_test['Outlet_Location_Type']=le.fit_transform(df_test['Outlet_Location_Type'])
df_test['Outlet_Type']=le.fit_transform(df_test['Outlet_Type'])

# %%
df_test.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103     20.75000                 0         0.007565         13
# 1             1067      8.30000                 1         0.038428          4
# 2             1406     14.60000                 0         0.099575         11
# 3              809      7.31500                 0         0.015388         13
# 4             1184     12.95504                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            1
# 2  241.7538                  0                       1998            1
# 3  155.0340                  2                       2007            1
# 4  234.2300                  5                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3
